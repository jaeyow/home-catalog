# %%
! python --version
# Out:
# Python 3.10.16

# %%
# %%capture
! pip install opencv-python
! pip install SpeechRecognition
! pip install --upgrade pip
! pip install instructor
! pip install pydantic
! pip show instructor
! pip install anthropic
! pip install python-dotenv
! pip install pandas
! pip install scikit-learn
! pip install boto3

# %%
import time
import speech_recognition as sr
import cv2
import os
import json

# Input video file path
video_path = "./keeptrack-house-video-with-audio-horizontal-720p.mov"
ffmpeg_path = "/usr/local/bin/ffmpeg"

# Output directory for saving frames
output_dir = 'frames'
os.makedirs(output_dir, exist_ok=True)

# Open the video file
cap = cv2.VideoCapture(video_path)

x_interval = 3
json_results = []

# Function to capture frames and transcriptions every x seconds
def capture_frames_and_transcriptions(video_capture, video_path, output_directory, interval=3):
    # Initialize the recognizer
    recognizer = sr.Recognizer()
    
    # Get the total number of frames in the video
    total_frames = int(video_capture.get(cv2.CAP_PROP_FRAME_COUNT))
    # Get the frame rate of the video
    fps = video_capture.get(cv2.CAP_PROP_FPS)
    # Calculate the interval in frames
    frame_interval = int(fps * interval)
    
    frame_number = 0
    while frame_number < total_frames:
        # Set the position of the video to the current frame number
        video_capture.set(cv2.CAP_PROP_POS_FRAMES, frame_number)
        
        # Read the frame at the current position
        success, frame = video_capture.read()
        
        if success:
            # Save the frame as a PNG file
            output_file = os.path.join(output_directory, f'frame_at_{frame_number // fps:.2f}_seconds.png')
            cv2.imwrite(output_file, frame)
            print(f'Successfully saved frame at {frame_number // fps:.2f} seconds to {output_file}')
            
            # Extract audio segment
            audio_output_file = os.path.join(output_directory, f'audio_at_{frame_number // fps:.2f}_seconds.wav')
            os.system(f'{ffmpeg_path} -loglevel error -i {video_path} -ss {frame_number // fps} -t {interval} -q:a 0 -map a {audio_output_file}')
            
            # Recognize the speech in the audio segment
            with sr.AudioFile(audio_output_file) as source:
                audio = recognizer.record(source)
                try:
                    transcription = recognizer.recognize_google(audio)
                    print(f'Transcription at {frame_number // fps:.2f} seconds: {transcription}')
                except sr.UnknownValueError:
                    print(f'Could not understand audio at {frame_number // fps:.2f} seconds')
                except sr.RequestError as e:
                    print(f'Could not request results from Google Speech Recognition service; {e}')

            # Save the results in json_results
            json_results.append({
                'timestamp': frame_number // fps,
                'frame': output_file,
                'audio': audio_output_file,
                'transcription': transcription if 'transcription' in locals() else None
            })
        else:
            print(f'Failed to capture frame at {frame_number // fps:.2f} seconds')
            
        # Move to the next frame interval
        frame_number += frame_interval
    
        # Define the output file path
        json_output_file = os.path.join(output_dir, 'json_results.json')

        # Save the json_results to the file
        with open(json_output_file, 'w') as f:
            json.dump(json_results, f, indent=4)


start_time = time.time()
# Capture frames and transcriptions every 3 secondsimport json
capture_frames_and_transcriptions(cap, video_path, output_dir, interval=x_interval)
end_time = time.time()

# Release the video capture object
cap.release()

print(f'Finished capturing frames and transcriptions every {x_interval} seconds in {end_time - start_time:.2f} seconds.')

# %%
# AWS Bedrock Claude price per 1,000 tokens for input and output tokens
model_price_list = {
    "haiku": {
        "input": 0.00025,
        "output": 0.00125,
        "input_batch": 0.000125,
        "output_batch": 0.000625,
    },
    "sonnet": {
        "input": 0.003,
        "output": 0.015,
        "input_batch": 0.0015,
        "output_batch": 0.0075,
    },
    "opus": {
        "input": 0.015,
        "output": 0.075,
        "input_batch": 0.0075,
        "output_batch": 0.0375,
    },
}

def calclulate_usage_and_cost(completion, price_list, image_frame="N/A"):
    """
    calclulate_usage_and_cost calculates the cost of the completion.
    Calculate cost (for Claude 3). https://aws.amazon.com/bedrock/pricing/
    """
    
    models = ["haiku", "sonnet", "opus"]

    model_name = completion.model.lower()
    model = next((m for m in models if m in model_name), None)
    
    if model in models:
        usd_cost_per_k_input_tokens = price_list[model]["input"]
        usd_cost_per_k_output_tokens = price_list[model]["output"]
    else:
        print(f"Unknown model: {completion.model}, cannot calculate cost.")
        return
    
    usage_cost = {
        "image_frame": image_frame,
        "input_tokens": completion.usage.input_tokens,
        "output_tokens": completion.usage.output_tokens,
        "model": completion.model,
        "total_cost": round((completion.usage.input_tokens * usd_cost_per_k_input_tokens + completion.usage.output_tokens * usd_cost_per_k_output_tokens) / 1000, 6)
    }
    
    cost_input_tokens = (completion.usage.input_tokens * usd_cost_per_k_input_tokens) / 1000
    cost_output_tokens = (completion.usage.output_tokens * usd_cost_per_k_output_tokens) / 1000
    print(f"Input tokens  : {completion.usage.input_tokens}, cost: USD {round(cost_input_tokens, 6)}")
    print(f"Output tokens : {completion.usage.output_tokens}, cost: USD {round(cost_output_tokens, 6)}")
    print(f"LLM Model     : {completion.model}")
    print(f"Total cost    : USD {round(cost_input_tokens + cost_output_tokens, 6)} for this call.\n")
    
    return usage_cost

# # Test cases for the calclulate_usage_and_cost function
# class Completion:
#     def __init__(self, model, input_tokens, output_tokens):
#         self.model = model
#         self.usage = self.Usage(input_tokens, output_tokens)
    
#     class Usage:
#         def __init__(self, input_tokens, output_tokens):
#             self.input_tokens = input_tokens
#             self.output_tokens = output_tokens

# # Test case 1: Model haiku
# completion_haiku = Completion(model="haiku-123", input_tokens=1000, output_tokens=2000)
# calclulate_usage_and_cost(completion_haiku, model_price_list)

# # Test case 2: Model sonnet
# completion_sonnet = Completion(model="sonnet-456", input_tokens=1000, output_tokens=2000)
# calclulate_usage_and_cost(completion_sonnet, model_price_list)

# # Test case 3: Model opus
# completion_opus = Completion(model="opus-234", input_tokens=1000, output_tokens=2000)
# calclulate_usage_and_cost(completion_opus, model_price_list)

# # Test case 4: Unknown model
# completion_unknown = Completion(model="unknown", input_tokens=1000, output_tokens=2000)
# calclulate_usage_and_cost(completion_unknown, model_price_list)

# %%
import base64
from IPython.display import Image, display

def mermaid_graph(graph, scale=2):
    graphbytes = graph.encode("ascii")
    base64_bytes = base64.b64encode(graphbytes)
    base64_string = base64_bytes.decode("ascii")
    # print(base64_string)
    display(
        Image(
            url=f"https://mermaid.ink/img/{base64_string}"
        )
    )

mermaid_graph("""
graph LR;
    A[Start] --> B[Target Video - 165,000 tokens]

    subgraph "Step 1: Initial Extraction"
        B --> C1[Gemini Model Initial Prompt - 10,000 tokens]
        C1 --> D1{CSV Validation}
        D1 -->|Valid| E1[Output 1]
        D1 -->|Invalid| FX1[Gemini CSV Fixer Model]
        FX1 --> D1
    end

    subgraph "Step 2: Expand Extraction"
        B & E1 --> C2[Gemini Model Secondary Prompt - 2000-5000 tokens]
        C2 --> D2{CSV Validation}
        D2 -->|Valid| E2[Output 2]
        D2 -->|Invalid| FX2[Gemini CSV Fixer Model]
        FX2 --> D2
    end

    subgraph "Step 3: Finalize Extraction"
        B & E1 & E2 --> C3[Gemini Model Final Prompt - 2000-5000 tokens]
        C3 --> D3{CSV Validation}
        D3 -->|Valid| E3[Final Output]
        D3 -->|Invalid| FX3[Gemini CSV Fixer Model]
        FX3 --> D3
    end

    E3 --> F[Final Results]

    %% Styling
    style C1 fill:#b3d9ff,stroke:#333,stroke-width:1px
    style C2 fill:#b3d9ff,stroke:#333,stroke-width:1px
    style C3 fill:#b3d9ff,stroke:#333,stroke-width:1px
    style D1 fill:#f9f,stroke:#333,stroke-width:1px
    style D2 fill:#f9f,stroke:#333,stroke-width:1px
    style D3 fill:#f9f,stroke:#333,stroke-width:1px
    style FX1 fill:#ccffcc,stroke:#333,stroke-width:1px
    style FX2 fill:#ccffcc,stroke:#333,stroke-width:1px
    style FX3 fill:#ccffcc,stroke:#333,stroke-width:1px
""")
# Out:
# <img src="https://mermaid...."/>

# %%
import os
import anthropic
import instructor
from dotenv import load_dotenv
import pandas as pd
import shutil

load_dotenv(verbose=True, dotenv_path=".env")

client = anthropic.AnthropicBedrock(
    aws_access_key=os.getenv("AWS_ACCESS_KEY_ID"),
    aws_secret_key=os.getenv("AWS_SECRET_ACCESS_KEY"),
    aws_session_token=os.getenv("AWS_SESSION_TOKEN"),
    aws_region=os.getenv("AWS_DEFAULT_REGION"),
)

MODEL_ID = "anthropic.claude-3-haiku-20240307-v1:0"     # Claude 3 Haiku  
# MODEL_ID = "anthropic.claude-3-sonnet-20240229-v1:0"    # Claude 3 Sonnet


# Regarding the LLM model choice, I would start with the cheapest option (Haiku). Depending on the tasks, the smallest 
# model might be sufficient. You will have to do some trial and error here. I found that the smallest model
# at times will have difficulty following certain instructions.
# For example, asking the LLM to summarise a body of text and constraining the summary say from minimum 100 and maximum 500 characters,
# the smallest model will sometimes fail to generate a summary that is within the character count constraints. In such cases,
# you might have to try a larger model.

instructor_client = instructor.from_anthropic(
    client,
    max_tokens=8192*2,
    model=MODEL_ID
)

# %%
from pydantic import BaseModel

# Define your desired output structure
class UserInfo(BaseModel):
    name: str
    age: int

user_info = instructor_client.chat.completions.create(
    response_model=UserInfo,
    messages=[{"role": "user", "content": "John Doe is 30 years old."}]
    )

print(user_info.name)
#> John Doe
print(user_info.age)
#> 30
# Out:
# John Doe
# 30

# %%
from typing import List
from pydantic import BaseModel, Field
from instructor.retry import InstructorRetryException
import warnings
import base64
import json

warnings.filterwarnings("ignore")

FIRST_PASS_SYSTEM_PROMPT = """
You are an expert insurance agent who excels at cataloging all the items in a home based on images and voice transcriptions. The images and transcriptions
are extracted from a video every 3 seconds.  The purpose of this task is to automate the process of cataloging items for contents insurance. Do not
include parts of the home itself, only items that would be covered by insurance. It is importatnt to count the number of items accurately and mention the count,
color, size, and brand if visible, in the item description. Include everything visible, including items in the foreground and background.

For each room in the house, identify and list all the items you can find in this image.
"""
# Return the list in JSON format as:
# {
#     "catalog_items": [
#         {"item_number": 1, "item_name": "sofa", "item_description": "red three seater sofa"},
#         {"item_number": 2, "item_name": "LCD TV", "item_description": "Samsung 55 inch smart TV"},
#         {"item_number": 3, "item_name": "Dishwasher", "item_description": "Bosch 12 place setting dishwasher"}
#     ]
# }


class CatalogItem(BaseModel):
    """
    Response model for a catalog item.
    """
    item_no: int = Field(..., description="The sequential number of the catalog item.")
    item_name: str = Field(..., description="A name for this catalog item.")
    item_desc: str = Field(..., description="A short description of this catalog item.")
    room_loc: str = Field(..., description="The room location in the house of this catalog item.")

class CatalogItems(BaseModel):
    """
    Response model for a list of catalog items.
    """
    items: List[CatalogItem] = Field(..., description="A list of catalog items in a house.")

class HomeCatalogger:
    """
    Catalog all the items in a home based on the images and voice transcriptions provided.
    """

    def __init__(self, client):
        self.client = client

    def catalog(self, image_path: str) -> CatalogItems:
        try:
            with open(image_path, "rb") as image_file:
                image_data = base64.b64encode(image_file.read()).decode("utf-8")

            catalog, completion = self.client.chat.completions.create_with_completion(
                messages=[
                    {"role": "user",
                        "content": [
                            {
                                "type": "image",
                                "source": {
                                    "type": "base64",
                                    "media_type": "image/png",
                                    "data": image_data
                                }
                            },
                            {
                                "type": "text",
                                "text": f"This is the image frame: {image_path}"
                            }
                        ]
                    }
                ],
                system=FIRST_PASS_SYSTEM_PROMPT,
                response_model=CatalogItems,
                temperature=0.0,
                max_retries=1,
            )

            # print(f"LLM Catalogging...")
            # print(catalog.model_dump_json(indent=2))
            # print()
            cost = calclulate_usage_and_cost(completion, model_price_list, os.path.basename(image_path))
            # print()
            return catalog, cost

        except InstructorRetryException as e:
            print(e)
            print(f"Retries attempted: {e.n_attempts}")
            print(e.last_completion)


# Initialize the HomeCatalogger with the instructor client
home_catalogger = HomeCatalogger(instructor_client)

# Load the JSON results
with open("./frames/json_results.json", "r") as file:
    json_results = json.load(file)

# Extract the first x image frames
image_frames = [item["frame"] for item in json_results[:30] ]

catalog_items = []
llm_costs = []
# Iterate through the image frames and pass each image to the catalogger
for frame in image_frames:
    print(f"Cataloging items in image: {frame}")
    catalog, cost = home_catalogger.catalog(frame)
    catalog_items.extend(catalog.items)
    llm_costs.append(cost)

# # Path to an example image
# output_dir = "frames" # re-declaring here... you can do it once at the top
# example_image_path = os.path.join(output_dir, "frame_at_63.00_seconds.png")

# # Catalog the items in the example image
# catalog_items = home_catalogger.catalog(example_image_path)

# Print the cataloged items
print(catalog_items)
print(llm_costs)
# Out:
# Cataloging items in image: frames/frame_at_0.00_seconds.png
# Input tokens  : 2044, cost: USD 0.000511
# Output tokens : 156, cost: USD 0.000195
# LLM Model     : claude-3-haiku-20240307
# Total cost    : USD 0.000706 for this call.
#
# Cataloging items in image: frames/frame_at_3.00_seconds.png
# Input tokens  : 2044, cost: USD 0.000511
# Output tokens : 347, cost: USD 0.000434
# LLM Model     : claude-3-haiku-20240307
# Total cost    : USD 0.000945 for this call.
#
# Cataloging items in image: frames/frame_at_6.00_seconds.png
# Input tokens  : 2044, cost: USD 0.000511
# Output tokens : 378, cost: USD 0.000473
# LLM Model     : claude-3-haiku-20240307
# Total cost    : USD 0.000983 for this call.
#
# Cataloging items in image: frames/frame_at_9.00_seconds.png
# Input tokens  : 2044, cost: USD 0.000511
# Output tokens : 380, cost: USD 0.000475
# LLM Model     : claude-3-haiku-20240307
# Total cost    : USD 0.000986 for this call.
#
# Cataloging items in image: frames/frame_at_12.00_seconds.png
# Input tokens  : 2044, cost: USD 0.000511
# Output tokens : 283, cost: USD 0.000354
# LLM Model     : claude-3-haiku-20240307
# Total cost    : USD 0.000865 for this call.
#
# Cataloging items in image: frames/frame_at_15.00_seconds.png
# Input tokens  : 2044, cost: USD 0.000511
# Output tokens : 208, cost: USD 0.00026
# LLM Model     : claude-3-haiku-20240307
# Total cost    : USD 0.000771 for this call.
#
# Cataloging items in image: frames/frame_at_18.00_seconds.png
# Input tokens  : 2044, cost: USD 0.000511
# Output tokens : 271, cost: USD 0.000339
# LLM Model     : claude-3-haiku-20240307
# Total cost    : USD 0.00085 for this call.
#
# Cataloging items in image: frames/frame_at_21.00_seconds.png
# Input tokens  : 2044, cost: USD 0.000511
# Output tokens : 366, cost: USD 0.000458
# LLM Model     : claude-3-haiku-20240307
# Total cost    : USD 0.000969 for this call.
#
# Cataloging items in image: frames/frame_at_24.00_seconds.png
# Input tokens  : 2044, cost: USD 0.000511
# Output tokens : 210, cost: USD 0.000263
# LLM Model     : claude-3-haiku-20240307
# Total cost    : USD 0.000774 for this call.
#
# Cataloging items in image: frames/frame_at_27.00_seconds.png
# Input tokens  : 2044, cost: USD 0.000511
# Output tokens : 203, cost: USD 0.000254
# LLM Model     : claude-3-haiku-20240307
# Total cost    : USD 0.000765 for this call.
#
# Cataloging items in image: frames/frame_at_30.00_seconds.png
# Input tokens  : 2044, cost: USD 0.000511
# Output tokens : 390, cost: USD 0.000487
# LLM Model     : claude-3-haiku-20240307
# Total cost    : USD 0.000999 for this call.
#
# Cataloging items in image: frames/frame_at_33.00_seconds.png
# Input tokens  : 2044, cost: USD 0.000511
# Output tokens : 353, cost: USD 0.000441
# LLM Model     : claude-3-haiku-20240307
# Total cost    : USD 0.000952 for this call.
#
# Cataloging items in image: frames/frame_at_36.00_seconds.png
# Input tokens  : 2044, cost: USD 0.000511
# Output tokens : 319, cost: USD 0.000399
# LLM Model     : claude-3-haiku-20240307
# Total cost    : USD 0.00091 for this call.
#
# Cataloging items in image: frames/frame_at_39.00_seconds.png
# Input tokens  : 2044, cost: USD 0.000511
# Output tokens : 288, cost: USD 0.00036
# LLM Model     : claude-3-haiku-20240307
# Total cost    : USD 0.000871 for this call.
#
# Cataloging items in image: frames/frame_at_42.00_seconds.png
# Input tokens  : 2044, cost: USD 0.000511
# Output tokens : 207, cost: USD 0.000259
# LLM Model     : claude-3-haiku-20240307
# Total cost    : USD 0.00077 for this call.
#
# Cataloging items in image: frames/frame_at_45.00_seconds.png
# Input tokens  : 2044, cost: USD 0.000511
# Output tokens : 106, cost: USD 0.000132
# LLM Model     : claude-3-haiku-20240307
# Total cost    : USD 0.000644 for this call.
#
# Cataloging items in image: frames/frame_at_48.00_seconds.png
# Input tokens  : 2044, cost: USD 0.000511
# Output tokens : 285, cost: USD 0.000356
# LLM Model     : claude-3-haiku-20240307
# Total cost    : USD 0.000867 for this call.
#
# Cataloging items in image: frames/frame_at_51.00_seconds.png
# Input tokens  : 2044, cost: USD 0.000511
# Output tokens : 278, cost: USD 0.000348
# LLM Model     : claude-3-haiku-20240307
# Total cost    : USD 0.000859 for this call.
#
# Cataloging items in image: frames/frame_at_54.00_seconds.png
# Input tokens  : 2044, cost: USD 0.000511
# Output tokens : 266, cost: USD 0.000333
# LLM Model     : claude-3-haiku-20240307
# Total cost    : USD 0.000844 for this call.
#
# Cataloging items in image: frames/frame_at_57.00_seconds.png
# Input tokens  : 2044, cost: USD 0.000511
# Output tokens : 215, cost: USD 0.000269
# LLM Model     : claude-3-haiku-20240307
# Total cost    : USD 0.00078 for this call.
#
# Cataloging items in image: frames/frame_at_60.00_seconds.png
# Input tokens  : 2044, cost: USD 0.000511
# Output tokens : 342, cost: USD 0.000427
# LLM Model     : claude-3-haiku-20240307
# Total cost    : USD 0.000939 for this call.
#
# Cataloging items in image: frames/frame_at_63.00_seconds.png
# Input tokens  : 2044, cost: USD 0.000511
# Output tokens : 339, cost: USD 0.000424
# LLM Model     : claude-3-haiku-20240307
# Total cost    : USD 0.000935 for this call.
#
# Cataloging items in image: frames/frame_at_66.00_seconds.png
# Input tokens  : 2044, cost: USD 0.000511
# Output tokens : 404, cost: USD 0.000505
# LLM Model     : claude-3-haiku-20240307
# Total cost    : USD 0.001016 for this call.
#
# Cataloging items in image: frames/frame_at_69.00_seconds.png
# Input tokens  : 2044, cost: USD 0.000511
# Output tokens : 282, cost: USD 0.000353
# LLM Model     : claude-3-haiku-20240307
# Total cost    : USD 0.000864 for this call.
#
# Cataloging items in image: frames/frame_at_72.00_seconds.png
# Input tokens  : 2044, cost: USD 0.000511
# Output tokens : 325, cost: USD 0.000406
# LLM Model     : claude-3-haiku-20240307
# Total cost    : USD 0.000917 for this call.
#
# Cataloging items in image: frames/frame_at_75.00_seconds.png
# Input tokens  : 2044, cost: USD 0.000511
# Output tokens : 398, cost: USD 0.000498
# LLM Model     : claude-3-haiku-20240307
# Total cost    : USD 0.001009 for this call.
#
# Cataloging items in image: frames/frame_at_78.00_seconds.png
# Input tokens  : 2044, cost: USD 0.000511
# Output tokens : 280, cost: USD 0.00035
# LLM Model     : claude-3-haiku-20240307
# Total cost    : USD 0.000861 for this call.
#
# Cataloging items in image: frames/frame_at_81.00_seconds.png
# Input tokens  : 2044, cost: USD 0.000511
# Output tokens : 156, cost: USD 0.000195
# LLM Model     : claude-3-haiku-20240307
# Total cost    : USD 0.000706 for this call.
#
# Cataloging items in image: frames/frame_at_84.00_seconds.png
# Input tokens  : 2044, cost: USD 0.000511
# Output tokens : 105, cost: USD 0.000131
# LLM Model     : claude-3-haiku-20240307
# Total cost    : USD 0.000642 for this call.
#
# Cataloging items in image: frames/frame_at_87.00_seconds.png
# Input tokens  : 2044, cost: USD 0.000511
# Output tokens : 324, cost: USD 0.000405
# LLM Model     : claude-3-haiku-20240307
# Total cost    : USD 0.000916 for this call.
#
# [CatalogItem(item_no=1, item_name='Sofa', item_desc='A beige sofa in the living room area', room_loc='Living Room'), CatalogItem(item_no=2, item_name='Hallway', item_desc='A long hallway with tile flooring leading to other rooms', room_loc='Hallway'), CatalogItem(item_no=1, item_name='Sofa', item_desc='A large, beige sofa with throw pillows in the living room area', room_loc='Living Room'), CatalogItem(item_no=2, item_name='Ceiling Fan', item_desc='A ceiling fan with 3 blades installed in the living room', room_loc='Living Room'), CatalogItem(item_no=3, item_name='Wall Decor', item_desc='A framed wall art piece hanging on the wall in the living room', room_loc='Living Room'), CatalogItem(item_no=4, item_name='Dining Table', item_desc='A rectangular wooden dining table with 4 chairs in the dining area', room_loc='Dining Room'), CatalogItem(item_no=5, item_name='Pendant Light', item_desc='A hanging pendant light fixture over the dining table', room_loc='Dining Room'), CatalogItem(item_no=1, item_name='Sofa', item_desc='A large, white sofa with throw pillows', room_loc='Living Room'), CatalogItem(item_no=2, item_name='Armchair', item_desc='A green, upholstered armchair', room_loc='Living Room'), CatalogItem(item_no=3, item_name='Coffee Table', item_desc='A round, wooden coffee table with a glass top', room_loc='Living Room'), CatalogItem(item_no=4, item_name='TV Stand', item_desc='A wooden TV stand with shelves for storage', room_loc='Living Room'), CatalogItem(item_no=5, item_name='Wall Art', item_desc='A framed abstract wall art piece', room_loc='Living Room'), CatalogItem(item_no=6, item_name='Decorative Vase', item_desc='A ceramic vase with a plant inside', room_loc='Living Room'), CatalogItem(item_no=1, item_name='Sofa', item_desc='A large, light-colored sofa with throw pillows', room_loc='Living Room'), CatalogItem(item_no=2, item_name='Coffee Table', item_desc='A round, wooden coffee table with a glass top', room_loc='Living Room'), CatalogItem(item_no=3, item_name='TV Stand', item_desc='A wooden TV stand with shelves for storage', room_loc='Living Room'), CatalogItem(item_no=4, item_name='Wall Art', item_desc='A large, abstract wall art piece', room_loc='Living Room'), CatalogItem(item_no=5, item_name='Ceiling Fan', item_desc='A white ceiling fan with 4 blades', room_loc='Living Room'), CatalogItem(item_no=6, item_name='Potted Plant', item_desc='A small potted plant on the TV stand', room_loc='Living Room'), CatalogItem(item_no=1, item_name='Wooden table', item_desc='A rectangular wooden table with a glass top, located in the living room area.', room_loc='Living room'), CatalogItem(item_no=2, item_name='Decorative vase', item_desc='A glass vase containing flowers, placed on the wooden table.', room_loc='Living room'), CatalogItem(item_no=3, item_name='Throw pillow', item_desc='A yellow and white patterned throw pillow on the couch.', room_loc='Living room'), CatalogItem(item_no=4, item_name='Couch', item_desc='A white fabric couch in the living room area.', room_loc='Living room'), CatalogItem(item_no=1, item_name='Armchair', item_desc='A large, comfortable-looking green armchair', room_loc='Living Room'), CatalogItem(item_no=2, item_name='TV Stand', item_desc='A wooden TV stand with shelves for storage', room_loc='Living Room'), CatalogItem(item_no=3, item_name='Potted Plant', item_desc='A small potted plant on the TV stand', room_loc='Living Room'), CatalogItem(item_no=1, item_name='TV stand', item_desc='A wooden TV stand with shelves for storage', room_loc='Living room'), CatalogItem(item_no=2, item_name='Decorative vase', item_desc='A yellow decorative vase on the TV stand', room_loc='Living room'), CatalogItem(item_no=3, item_name='Potted plant', item_desc='A small potted plant on the TV stand', room_loc='Living room'), CatalogItem(item_no=4, item_name='Armchair', item_desc='A green upholstered armchair in the living room', room_loc='Living room'), CatalogItem(item_no=1, item_name='Wall Art', item_desc='A large abstr ...
# [{'image_frame': 'frame_at_0.00_seconds.png', 'input_tokens': 2044, 'output_tokens': 156, 'model': 'claude-3-haiku-20240307', 'total_cost': 0.000706}, {'image_frame': 'frame_at_3.00_seconds.png', 'input_tokens': 2044, 'output_tokens': 347, 'model': 'claude-3-haiku-20240307', 'total_cost': 0.000945}, {'image_frame': 'frame_at_6.00_seconds.png', 'input_tokens': 2044, 'output_tokens': 378, 'model': 'claude-3-haiku-20240307', 'total_cost': 0.000983}, {'image_frame': 'frame_at_9.00_seconds.png', 'input_tokens': 2044, 'output_tokens': 380, 'model': 'claude-3-haiku-20240307', 'total_cost': 0.000986}, {'image_frame': 'frame_at_12.00_seconds.png', 'input_tokens': 2044, 'output_tokens': 283, 'model': 'claude-3-haiku-20240307', 'total_cost': 0.000865}, {'image_frame': 'frame_at_15.00_seconds.png', 'input_tokens': 2044, 'output_tokens': 208, 'model': 'claude-3-haiku-20240307', 'total_cost': 0.000771}, {'image_frame': 'frame_at_18.00_seconds.png', 'input_tokens': 2044, 'output_tokens': 271, 'model': 'claude-3-haiku-20240307', 'total_cost': 0.00085}, {'image_frame': 'frame_at_21.00_seconds.png', 'input_tokens': 2044, 'output_tokens': 366, 'model': 'claude-3-haiku-20240307', 'total_cost': 0.000969}, {'image_frame': 'frame_at_24.00_seconds.png', 'input_tokens': 2044, 'output_tokens': 210, 'model': 'claude-3-haiku-20240307', 'total_cost': 0.000774}, {'image_frame': 'frame_at_27.00_seconds.png', 'input_tokens': 2044, 'output_tokens': 203, 'model': 'claude-3-haiku-20240307', 'total_cost': 0.000765}, {'image_frame': 'frame_at_30.00_seconds.png', 'input_tokens': 2044, 'output_tokens': 390, 'model': 'claude-3-haiku-20240307', 'total_cost': 0.000999}, {'image_frame': 'frame_at_33.00_seconds.png', 'input_tokens': 2044, 'output_tokens': 353, 'model': 'claude-3-haiku-20240307', 'total_cost': 0.000952}, {'image_frame': 'frame_at_36.00_seconds.png', 'input_tokens': 2044, 'output_tokens': 319, 'model': 'claude-3-haiku-20240307', 'total_cost': 0.00091}, {'image_frame': 'frame_at_39.00_seconds.png', 'input_tokens': 2044, 'output_tokens': 288, 'model': 'claude-3-haiku-20240307', 'total_cost': 0.000871}, {'image_frame': 'frame_at_42.00_seconds.png', 'input_tokens': 2044, 'output_tokens': 207, 'model': 'claude-3-haiku-20240307', 'total_cost': 0.00077}, {'image_frame': 'frame_at_45.00_seconds.png', 'input_tokens': 2044, 'output_tokens': 106, 'model': 'claude-3-haiku-20240307', 'total_cost': 0.000643}, {'image_frame': 'frame_at_48.00_seconds.png', 'input_tokens': 2044, 'output_tokens': 285, 'model': 'claude-3-haiku-20240307', 'total_cost': 0.000867}, {'image_frame': 'frame_at_51.00_seconds.png', 'input_tokens': 2044, 'output_tokens': 278, 'model': 'claude-3-haiku-20240307', 'total_cost': 0.000858}, {'image_frame': 'frame_at_54.00_seconds.png', 'input_tokens': 2044, 'output_tokens': 266, 'model': 'claude-3-haiku-20240307', 'total_cost': 0.000844}, {'image_frame': 'frame_at_57.00_seconds.png', 'input_tokens': 2044, 'output_tokens': 215, 'model': 'claude-3-haiku-20240307', 'total_cost': 0.00078}, {'image_frame': 'frame_at_60.00_seconds.png', 'input_tokens': 2044, 'output_tokens': 342, 'model': 'claude-3-haiku-20240307', 'total_cost': 0.000938}, {'image_frame': 'frame_at_63.00_seconds.png', 'input_tokens': 2044, 'output_tokens': 339, 'model': 'claude-3-haiku-20240307', 'total_cost': 0.000935}, {'image_frame': 'frame_at_66.00_seconds.png', 'input_tokens': 2044, 'output_tokens': 404, 'model': 'claude-3-haiku-20240307', 'total_cost': 0.001016}, {'image_frame': 'frame_at_69.00_seconds.png', 'input_tokens': 2044, 'output_tokens': 282, 'model': 'claude-3-haiku-20240307', 'total_cost': 0.000863}, {'image_frame': 'frame_at_72.00_seconds.png', 'input_tokens': 2044, 'output_tokens': 325, 'model': 'claude-3-haiku-20240307', 'total_cost': 0.000917}, {'image_frame': 'frame_at_75.00_seconds.png', 'input_tokens': 2044, 'output_tokens': 398, 'model': 'claude-3-haiku-20240307', 'total_cost': 0.001008}, {'image_frame': 'frame_at_78.00_seconds.png', 'input_tokens': 2044, 'output_token ...

# %%
# Fix item numbers to be sequential
for idx, item in enumerate(catalog_items, start=1):
    item.item_no = idx

for item in catalog_items:
    # print(f"Frame {item.}, Item {item.item_no}: {item.item_name} - {item.item_desc}")
    print(item)
    
total_input_tokens = sum(cost['input_tokens'] for cost in llm_costs)
total_output_tokens = sum(cost['output_tokens'] for cost in llm_costs)
total_cost_usd = sum(cost['total_cost'] for cost in llm_costs)

print()
print(f"Total input tokens: {total_input_tokens}")
print(f"Total output tokens: {total_output_tokens}")
print(f"Total cost in USD: {total_cost_usd:.6f}")
# Out:
# item_no=1 item_name='Sofa' item_desc='A beige sofa in the living room area' room_loc='Living Room'
# item_no=2 item_name='Hallway' item_desc='A long hallway with tile flooring leading to other rooms' room_loc='Hallway'
# item_no=3 item_name='Sofa' item_desc='A large, beige sofa with throw pillows in the living room area' room_loc='Living Room'
# item_no=4 item_name='Ceiling Fan' item_desc='A ceiling fan with 3 blades installed in the living room' room_loc='Living Room'
# item_no=5 item_name='Wall Decor' item_desc='A framed wall art piece hanging on the wall in the living room' room_loc='Living Room'
# item_no=6 item_name='Dining Table' item_desc='A rectangular wooden dining table with 4 chairs in the dining area' room_loc='Dining Room'
# item_no=7 item_name='Pendant Light' item_desc='A hanging pendant light fixture over the dining table' room_loc='Dining Room'
# item_no=8 item_name='Sofa' item_desc='A large, white sofa with throw pillows' room_loc='Living Room'
# item_no=9 item_name='Armchair' item_desc='A green, upholstered armchair' room_loc='Living Room'
# item_no=10 item_name='Coffee Table' item_desc='A round, wooden coffee table with a glass top' room_loc='Living Room'
# item_no=11 item_name='TV Stand' item_desc='A wooden TV stand with shelves for storage' room_loc='Living Room'
# item_no=12 item_name='Wall Art' item_desc='A framed abstract wall art piece' room_loc='Living Room'
# item_no=13 item_name='Decorative Vase' item_desc='A ceramic vase with a plant inside' room_loc='Living Room'
# item_no=14 item_name='Sofa' item_desc='A large, light-colored sofa with throw pillows' room_loc='Living Room'
# item_no=15 item_name='Coffee Table' item_desc='A round, wooden coffee table with a glass top' room_loc='Living Room'
# item_no=16 item_name='TV Stand' item_desc='A wooden TV stand with shelves for storage' room_loc='Living Room'
# item_no=17 item_name='Wall Art' item_desc='A large, abstract wall art piece' room_loc='Living Room'
# item_no=18 item_name='Ceiling Fan' item_desc='A white ceiling fan with 4 blades' room_loc='Living Room'
# item_no=19 item_name='Potted Plant' item_desc='A small potted plant on the TV stand' room_loc='Living Room'
# item_no=20 item_name='Wooden table' item_desc='A rectangular wooden table with a glass top, located in the living room area.' room_loc='Living room'
# item_no=21 item_name='Decorative vase' item_desc='A glass vase containing flowers, placed on the wooden table.' room_loc='Living room'
# item_no=22 item_name='Throw pillow' item_desc='A yellow and white patterned throw pillow on the couch.' room_loc='Living room'
# item_no=23 item_name='Couch' item_desc='A white fabric couch in the living room area.' room_loc='Living room'
# item_no=24 item_name='Armchair' item_desc='A large, comfortable-looking green armchair' room_loc='Living Room'
# item_no=25 item_name='TV Stand' item_desc='A wooden TV stand with shelves for storage' room_loc='Living Room'
# item_no=26 item_name='Potted Plant' item_desc='A small potted plant on the TV stand' room_loc='Living Room'
# item_no=27 item_name='TV stand' item_desc='A wooden TV stand with shelves for storage' room_loc='Living room'
# item_no=28 item_name='Decorative vase' item_desc='A yellow decorative vase on the TV stand' room_loc='Living room'
# item_no=29 item_name='Potted plant' item_desc='A small potted plant on the TV stand' room_loc='Living room'
# item_no=30 item_name='Armchair' item_desc='A green upholstered armchair in the living room' room_loc='Living room'
# item_no=31 item_name='Wall Art' item_desc='A large abstract wall art piece with geometric patterns in shades of pink, gray, and black.' room_loc='Living Room'
# item_no=32 item_name='Wooden Console Table' item_desc='A wooden console table with shelves, placed against the wall.' room_loc='Living Room'
# item_no=33 item_name='Decorative Pumpkins' item_desc='Two decorative pumpkins, one yellow and one green, placed on top of the console table.' room_loc='Living Room'
# item_no=34 item_name='Floor Lamp' item_desc='A black floor lamp with a single light fixture, standing next to the console table.' room_loc='Living Room'
# item_no=35 item_name='Wall Mirror' item_desc='A rectangular wall mirror with a black metal frame, hung on the wall next to the console table.' room_loc='Living Room'
# item_no=36 item_name='Mirror' item_desc='A large arched black metal mirror mounted on the wall' room_loc='Entryway'
# item_no=37 item_name='Plant' item_desc='A potted green plant placed on a wooden bench' room_loc='Entryway'
# item_no=38 item_name='Bench' item_desc='A wooden bench placed against the wall' room_loc='Entryway'
# item_no=39 item_name='Painting' item_desc='A framed painting hanging on the wall' room_loc='Living Room'
# item_no=40 item_name='Potted Plant' item_desc='A small potted plant on the floor' room_loc='Living Room'
# item_no=41 item_name='Lamp' item_desc='A table lamp on the side table' room_loc='Living Room'
# item_no=42 item_name='Shelving Unit' item_desc='A white metal shelving unit with multiple shelves, holding various items like books, folders, and other office supplies.' room_loc='Office'
# item_no=43 item_name='Desk Chair' item_desc='A green upholstered desk chair.' room_loc='Office'
# item_no=44 item_name='Coat' item_desc='A black coat hanging on the shelving unit.' room_loc='Office'
# item_no=45 item_name='Folders' item_desc='Several folders and binders on the shelves.' room_loc='Office'
# item_no=46 item_name='Books' item_desc='A few books on the shelves.' room_loc='Office'
# item_no=47 item_name='Office Supplies' item_desc='Various office supplies like pens, pencils, and other small items on the shelves.' room_loc='Office'
# item_no=48 item_name='Shelving Unit' item_desc='A white metal shelving unit with multiple shelves, holding various items such as books, tools, and other household objects.' room_loc='Utility Room'
# item_no=49 item_name='Broom' item_desc='A black broom leaning against the shelving unit.' room_loc='Utility Room'
# item_no=50 item_name='Mop' item_desc='An orange mop head visible on the shelving unit.' room_loc='Utility Room'
# item_no=51 item_name='Cleaning Supplies' item_desc='Various cleaning supplies and bottles visible on the shelves.' room_loc='Utility Room'
# item_no=52 item_name='Toolbox' item_desc='A black toolbox on the bottom shelf of the shelving unit.' room_loc='Utility Room'
# item_no=53 item_name='Binders' item_desc='A stack of yellow binders on the shelf' room_loc='Office'
# item_no=54 item_name='Cleaning Supplies' item_desc='Various cleaning supplies and tools on the shelf' room_loc='Office'
# item_no=55 item_name='Backpack' item_desc='A black backpack on the shelf' room_loc='Office'
# item_no=56 item_name='Binders' item_desc='Another stack of yellow binders on the shelf' room_loc='Office'
# item_no=57 item_name='Miscellaneous Items' item_desc='Various other items like a bottle and tools on the shelf' room_loc='Office'
# item_no=58 item_name='Shelving unit' item_desc='A white metal shelving unit with multiple shelves holding various items' room_loc='Utility room'
# item_no=59 item_name='Sonos speakers' item_desc='Two black Sonos speakers on the shelves' room_loc='Utility room'
# item_no=60 item_name='Plastic storage containers' item_desc='Several yellow and black plastic storage containers on the shelves' room_loc='Utility room'
# item_no=61 item_name='Miscellaneous items' item_desc='Various other items such as a spray bottle and other small objects on the shelves' room_loc='Utility room'
# item_no=62 item_name='Binders' item_desc='A stack of yellow binders on the shelves' room_loc='Storage room'
# item_no=63 item_name='Charger' item_desc='An orange charger device on the shelf' room_loc='Storage room'
# item_no=64 item_name='Speakers' item_desc='A set of black speakers on the shelves' room_loc='Storage room'
# item_no=65 item_name='Charlie Walks' item_desc="A stack of 30 books with the title 'Charlie Walks' on the spine." room_loc='Shelving unit'
# item_no=66 item_name='Ladder' item_desc='A tall, orange ladder leaning against the wall' room_loc='Utility Room'
# item_no=67 item_name='Shelving Unit' item_desc='A metal shelving unit with various items stored on the shelves, including books, tools, and other household items' room_loc='Utility Room'
# item_no=68 item_name='Tool Bag' item_desc='An orange tool bag hanging on the shelving unit' room_loc='Utility Room'
# item_no=69 item_name='Toolbox' item_desc='A blue toolbox on the shelving unit' room_loc='Utility Room'
# item_no=70 item_name='Shelving Unit' item_desc='A white metal shelving unit with multiple shelves holding various items.' room_loc='Utility Room'
# item_no=71 item_name='Broom' item_desc='A red-handled broom leaning against the wall.' room_loc='Utility Room'
# item_no=72 item_name='Cleaning Supplies' item_desc='Various cleaning supplies and bottles on the shelves.' room_loc='Utility Room'
# item_no=73 item_name='Toolbox' item_desc='A black toolbox on one of the shelves.' room_loc='Utility Room'
# item_no=74 item_name='Sofa' item_desc='A large, beige sofa with brown and yellow throw pillows' room_loc='Living Room'
# item_no=75 item_name='Coffee Table' item_desc='A wooden coffee table with a glass top' room_loc='Living Room'
# item_no=76 item_name='Armchair' item_desc='A green armchair' room_loc='Living Room'
# item_no=77 item_name='Rug' item_desc='A large, patterned area rug on the floor' room_loc='Living Room'
# item_no=78 item_name='Pair of Shoes' item_desc='A pair of black shoes visible on the floor near the kitchen counter' room_loc='Kitchen'
# item_no=79 item_name='Kitchen Counter' item_desc='A black kitchen counter with drawers and cabinets' room_loc='Kitchen'
# item_no=80 item_name='Dining Table' item_desc='A rectangular dining table with chairs visible through the window' room_loc='Dining Room'
# item_no=81 item_name='Refrigerator' item_desc='A large stainless steel refrigerator with French doors' room_loc='Kitchen'
# item_no=82 item_name='Oven' item_desc='A built-in black oven with digital controls' room_loc='Kitchen'
# item_no=83 item_name='Cabinets' item_desc='White cabinets with black hardware lining the walls of the kitchen' room_loc='Kitchen'
# item_no=84 item_name='Countertop' item_desc='A light-colored quartz countertop with a few kitchen items on it' room_loc='Kitchen'
# item_no=85 item_name='Wall Decor' item_desc='A framed piece of wall art or decoration hanging on the kitchen wall' room_loc='Kitchen'
# item_no=86 item_name='Dining table' item_desc='A rectangular wooden dining table with 6 upholstered chairs around it.' room_loc='Dining room'
# item_no=87 item_name='Wall mirror' item_desc='A rectangular framed wall mirror hanging on the wall.' room_loc='Dining room'
# item_no=88 item_name='Decorative figurines' item_desc='Two small decorative figurines placed on the dining table.' room_loc='Dining room'
# item_no=89 item_name='Stools' item_desc='Two wooden stools placed near the dining table.' room_loc='Dining room'
# item_no=90 item_name='Sliding glass doors' item_desc='Large sliding glass doors leading to the backyard.' room_loc='Dining room'
# item_no=91 item_name='Kitchen counter' item_desc='A white kitchen counter with various items on it, including a cutting board, fruits, and other kitchen accessories.' room_loc='Kitchen'
# item_no=92 item_name='Bar stools' item_desc='Three wooden bar stools with white frames positioned at the kitchen counter.' room_loc='Kitchen'
# item_no=93 item_name='Wall mirror' item_desc='A rectangular wall mirror hanging on the wall in the kitchen area.' room_loc='Kitchen'
# item_no=94 item_name='Wall shelves' item_desc='A set of white wall shelves mounted on the wall, holding various decorative items.' room_loc='Kitchen'
# item_no=95 item_name='Oven' item_desc='A black built-in oven visible in the kitchen area.' room_loc='Kitchen'
# item_no=96 item_name='Armchair' item_desc='A gray tufted armchair positioned in the kitchen area.' room_loc='Kitchen'
# item_no=97 item_name='Dining Table' item_desc='A rectangular wooden dining table with a natural wood finish.' room_loc='Dining Room'
# item_no=98 item_name='Dining Chairs' item_desc='4 beige upholstered dining chairs around the table.' room_loc='Dining Room'
# item_no=99 item_name='Decorative Figurines' item_desc='3 white ceramic figurines on the dining table.' room_loc='Dining Room'
# item_no=100 item_name='Potted Plant' item_desc='A potted plant with green leaves on the dining table.' room_loc='Dining Room'
# item_no=101 item_name='Dining Table' item_desc='A rectangular wooden dining table with four chairs around it.' room_loc='Dining Room'
# item_no=102 item_name='Plant' item_desc='A small potted plant on the dining table.' room_loc='Dining Room'
# item_no=103 item_name='Wall Mirror' item_desc='A rectangular wall mirror hanging on the wall.' room_loc='Dining Room'
# item_no=104 item_name='Couch' item_desc='A gray upholstered couch in the adjacent room.' room_loc='Living Room'
# item_no=105 item_name='Coffee Table' item_desc='A wooden coffee table in front of the couch.' room_loc='Living Room'
# item_no=106 item_name='Dining Table' item_desc='A rectangular wooden dining table with 4 chairs around it.' room_loc='Dining Room'
# item_no=107 item_name='Refrigerator' item_desc='A black refrigerator with stainless steel handles.' room_loc='Kitchen'
# item_no=108 item_name='Wall Mirror' item_desc='A rectangular wall mirror with a silver frame.' room_loc='Dining Room'
# item_no=109 item_name='Dining Chairs' item_desc='4 gray upholstered dining chairs around the table.' room_loc='Dining Room'
# item_no=110 item_name='Wall Shelves' item_desc='A set of black wall-mounted shelves with various decor items.' room_loc='Dining Room'
# item_no=111 item_name='Potted Plant' item_desc='A small potted plant on the dining table.' room_loc='Dining Room'
# item_no=112 item_name='Refrigerator' item_desc='A large, stainless steel refrigerator with double doors' room_loc='Kitchen'
# item_no=113 item_name='Oven' item_desc='A built-in, black oven with a stainless steel finish' room_loc='Kitchen'
# item_no=114 item_name='Cabinets' item_desc='A set of dark, wooden cabinets with drawers and shelves' room_loc='Kitchen'
# item_no=115 item_name='Tile Flooring' item_desc='Dark gray tile flooring throughout the kitchen' room_loc='Kitchen'
# item_no=116 item_name='Drawers' item_desc='A set of black drawers with 3 drawers' room_loc='Kitchen'
# item_no=117 item_name='Cooking Utensils' item_desc='Various cooking utensils and tools on the counter' room_loc='Kitchen'
# item_no=118 item_name='Dishwasher' item_desc='A stainless steel Miele dishwasher with a digital display and control panel' room_loc='Kitchen'
# item_no=119 item_name='Microwave' item_desc='A stainless steel microwave oven with control panel' room_loc='Kitchen'
# item_no=120 item_name='Oven' item_desc='A stainless steel oven with control panel' room_loc='Kitchen'
# item_no=121 item_name='Shelves' item_desc='Black shelving unit with various kitchen items stored on it' room_loc='Kitchen'
# item_no=122 item_name='Canister' item_desc='A white ceramic canister on the shelves' room_loc='Kitchen'
# item_no=123 item_name='Drawer' item_desc='A drawer partially open, likely containing kitchen utensils' room_loc='Kitchen'
#
# Total input tokens: 61320
# Total output tokens: 8464
# Total cost in USD: 0.025910

# %%
import json

# Save catalog_items to catalog_items_first_pass.json
with open('catalog_items_first_pass.json', 'w') as f:
    json.dump([item.dict() for item in catalog_items], f, indent=4)

# Save llm_costs to llm_costs_first_pass.json
with open('llm_costs_first_pass.json', 'w') as f:
    json.dump(llm_costs, f, indent=4)

print('Saved catalog_items and llm_costs to JSON files.')
# Out:
# Saved catalog_items and llm_costs to JSON files.

# %%
from typing import List
from pydantic import BaseModel, Field
from instructor.retry import InstructorRetryException
import warnings
import base64
import json

warnings.filterwarnings("ignore")

SECOND_PASS_SYSTEM_PROMPT = """
You are an expert insurance agent who excels at cataloging all the items in a home based on images and voice transcriptions. The first pass of cataloging
has already been completed, and you are now tasked with reviewing and correcting the cataloged items. The images and transcriptions are extracted from a video and
have been cataloged by an AI model. It is your job to ensure that the duplicated items are removed, and any missing items are added to the catalog. Please review
the items carefully and make any necessary corrections.
"""

class HomeCatalogDeduplicator:
    """
    Make sure that the cataloged items are deduplicated and are not repeating in the same room location. But do not blatantly remove items,
    since it is possible that the same item is present in different rooms. If you find that an item is present in multiple rooms, make sure to
    keep the item in the room where it is most visible. If an item is present in multiple rooms and is equally visible in both rooms, keep the item
    in the room where it was first cataloged.
    """

    def __init__(self, client):
        self.client = client

    def deduplicate(self, catalog_items):
        try:
            catalog_items_deduped, completion = self.client.chat.completions.create_with_completion(
                messages=[
                    {"role": "user",
                        "content": [
                            {
                                "type": "text",
                                "text": f"This is the list of catalog items: {catalog_items}. Remove duplicates items as described in the prompt."
                            }
                        ]
                    }
                ],
                system=SECOND_PASS_SYSTEM_PROMPT,
                response_model=CatalogItems,
                temperature=0.0,
                max_retries=1,
            )

            cost = calclulate_usage_and_cost(completion, model_price_list)
            return catalog_items_deduped, cost

        except InstructorRetryException as e:
            print(e)
            print(f"Retries attempted: {e.n_attempts}")
            print(e.last_completion)


catalog_dedupe = HomeCatalogDeduplicator(instructor_client)

new_catalog_items, new_llm_cost = catalog_dedupe.deduplicate(catalog_items[:30])

print(new_catalog_items)
print(new_llm_cost)
# Out:
# Input tokens  : 2066, cost: USD 0.000516
# Output tokens : 1452, cost: USD 0.001815
# LLM Model     : claude-3-haiku-20240307
# Total cost    : USD 0.002331 for this call.
#
# items=[CatalogItem(item_no=1, item_name='Sofa', item_desc='A beige sofa in the living room area', room_loc='Living Room'), CatalogItem(item_no=2, item_name='Hallway', item_desc='A long hallway with tile flooring leading to other rooms', room_loc='Hallway'), CatalogItem(item_no=4, item_name='Ceiling Fan', item_desc='A ceiling fan with 3 blades installed in the living room', room_loc='Living Room'), CatalogItem(item_no=5, item_name='Wall Decor', item_desc='A framed wall art piece hanging on the wall in the living room', room_loc='Living Room'), CatalogItem(item_no=6, item_name='Dining Table', item_desc='A rectangular wooden dining table with 4 chairs in the dining area', room_loc='Dining Room'), CatalogItem(item_no=7, item_name='Pendant Light', item_desc='A hanging pendant light fixture over the dining table', room_loc='Dining Room'), CatalogItem(item_no=9, item_name='Armchair', item_desc='A green, upholstered armchair', room_loc='Living Room'), CatalogItem(item_no=10, item_name='Coffee Table', item_desc='A round, wooden coffee table with a glass top', room_loc='Living Room'), CatalogItem(item_no=11, item_name='TV Stand', item_desc='A wooden TV stand with shelves for storage', room_loc='Living Room'), CatalogItem(item_no=12, item_name='Wall Art', item_desc='A framed abstract wall art piece', room_loc='Living Room'), CatalogItem(item_no=13, item_name='Decorative Vase', item_desc='A ceramic vase with a plant inside', room_loc='Living Room'), CatalogItem(item_no=18, item_name='Ceiling Fan', item_desc='A white ceiling fan with 4 blades', room_loc='Living Room'), CatalogItem(item_no=19, item_name='Potted Plant', item_desc='A small potted plant on the TV stand', room_loc='Living Room'), CatalogItem(item_no=20, item_name='Wooden table', item_desc='A rectangular wooden table with a glass top, located in the living room area.', room_loc='Living room'), CatalogItem(item_no=21, item_name='Decorative vase', item_desc='A glass vase containing flowers, placed on the wooden table.', room_loc='Living room'), CatalogItem(item_no=22, item_name='Throw pillow', item_desc='A yellow and white patterned throw pillow on the couch.', room_loc='Living room'), CatalogItem(item_no=23, item_name='Couch', item_desc='A white fabric couch in the living room area.', room_loc='Living room'), CatalogItem(item_no=24, item_name='Armchair', item_desc='A large, comfortable-looking green armchair', room_loc='Living Room'), CatalogItem(item_no=25, item_name='TV Stand', item_desc='A wooden TV stand with shelves for storage', room_loc='Living Room'), CatalogItem(item_no=26, item_name='Potted Plant', item_desc='A small potted plant on the TV stand', room_loc='Living Room'), CatalogItem(item_no=27, item_name='TV stand', item_desc='A wooden TV stand with shelves for storage', room_loc='Living room'), CatalogItem(item_no=28, item_name='Decorative vase', item_desc='A yellow decorative vase on the TV stand', room_loc='Living room'), CatalogItem(item_no=29, item_name='Potted plant', item_desc='A small potted plant on the TV stand', room_loc='Living room'), CatalogItem(item_no=30, item_name='Armchair', item_desc='A green upholstered armchair in the living room', room_loc='Living room')]
# {'image_frame': 'N/A', 'input_tokens': 2066, 'output_tokens': 1452, 'model': 'claude-3-haiku-20240307', 'total_cost': 0.002332}

# %%
# Fix item numbers to be sequential
for idx, item in enumerate(new_catalog_items.items, start=1):
    item.item_no = idx


for item in new_catalog_items.items:
    print(item)
    
total_input_tokens = sum(cost['input_tokens'] for cost in llm_costs)
total_output_tokens = sum(cost['output_tokens'] for cost in llm_costs)
total_cost_usd = sum(cost['total_cost'] for cost in llm_costs)

print()
print(f"Total input tokens: {total_input_tokens}")
print(f"Total output tokens: {total_output_tokens}")
print(f"Total cost in USD: {total_cost_usd:.6f}")
# Out:
# item_no=1 item_name='Sofa' item_desc='A beige sofa in the living room area' room_loc='Living Room'
# item_no=2 item_name='Hallway' item_desc='A long hallway with tile flooring leading to other rooms' room_loc='Hallway'
# item_no=3 item_name='Ceiling Fan' item_desc='A ceiling fan with 3 blades installed in the living room' room_loc='Living Room'
# item_no=4 item_name='Wall Decor' item_desc='A framed wall art piece hanging on the wall in the living room' room_loc='Living Room'
# item_no=5 item_name='Dining Table' item_desc='A rectangular wooden dining table with 4 chairs in the dining area' room_loc='Dining Room'
# item_no=6 item_name='Pendant Light' item_desc='A hanging pendant light fixture over the dining table' room_loc='Dining Room'
# item_no=7 item_name='Armchair' item_desc='A green, upholstered armchair' room_loc='Living Room'
# item_no=8 item_name='Coffee Table' item_desc='A round, wooden coffee table with a glass top' room_loc='Living Room'
# item_no=9 item_name='TV Stand' item_desc='A wooden TV stand with shelves for storage' room_loc='Living Room'
# item_no=10 item_name='Wall Art' item_desc='A framed abstract wall art piece' room_loc='Living Room'
# item_no=11 item_name='Decorative Vase' item_desc='A ceramic vase with a plant inside' room_loc='Living Room'
# item_no=12 item_name='Ceiling Fan' item_desc='A white ceiling fan with 4 blades' room_loc='Living Room'
# item_no=13 item_name='Potted Plant' item_desc='A small potted plant on the TV stand' room_loc='Living Room'
# item_no=14 item_name='Wooden table' item_desc='A rectangular wooden table with a glass top, located in the living room area.' room_loc='Living room'
# item_no=15 item_name='Decorative vase' item_desc='A glass vase containing flowers, placed on the wooden table.' room_loc='Living room'
# item_no=16 item_name='Throw pillow' item_desc='A yellow and white patterned throw pillow on the couch.' room_loc='Living room'
# item_no=17 item_name='Couch' item_desc='A white fabric couch in the living room area.' room_loc='Living room'
# item_no=18 item_name='Armchair' item_desc='A large, comfortable-looking green armchair' room_loc='Living Room'
# item_no=19 item_name='TV Stand' item_desc='A wooden TV stand with shelves for storage' room_loc='Living Room'
# item_no=20 item_name='Potted Plant' item_desc='A small potted plant on the TV stand' room_loc='Living Room'
# item_no=21 item_name='TV stand' item_desc='A wooden TV stand with shelves for storage' room_loc='Living room'
# item_no=22 item_name='Decorative vase' item_desc='A yellow decorative vase on the TV stand' room_loc='Living room'
# item_no=23 item_name='Potted plant' item_desc='A small potted plant on the TV stand' room_loc='Living room'
# item_no=24 item_name='Armchair' item_desc='A green upholstered armchair in the living room' room_loc='Living room'
#
# Total input tokens: 61320
# Total output tokens: 8464
# Total cost in USD: 0.025910
