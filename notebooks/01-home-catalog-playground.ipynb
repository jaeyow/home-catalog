# %%
! python --version

# %%
# %%capture
! pip install opencv-python
! pip install SpeechRecognition
! pip install --upgrade pip
! pip install instructor
! pip install pydantic
! pip show instructor
! pip install anthropic
! pip install python-dotenv
! pip install pandas
! pip install scikit-learn
! pip install boto3

# %%
import time
import speech_recognition as sr
import cv2
import os
import json

# Input video file path
video_path = "./keeptrack-house-video-with-audio-horizontal-720p.mov"
ffmpeg_path = "/usr/local/bin/ffmpeg"

# Output directory for saving frames
output_dir = 'frames'
os.makedirs(output_dir, exist_ok=True)

# Open the video file
cap = cv2.VideoCapture(video_path)

x_interval = 3
json_results = []

# Function to capture frames and transcriptions every x seconds
def capture_frames_and_transcriptions(video_capture, video_path, output_directory, interval=3):
    # Initialize the recognizer
    recognizer = sr.Recognizer()
    
    # Get the total number of frames in the video
    total_frames = int(video_capture.get(cv2.CAP_PROP_FRAME_COUNT))
    # Get the frame rate of the video
    fps = video_capture.get(cv2.CAP_PROP_FPS)
    # Calculate the interval in frames
    frame_interval = int(fps * interval)
    
    frame_number = 0
    while frame_number < total_frames:
        # Set the position of the video to the current frame number
        video_capture.set(cv2.CAP_PROP_POS_FRAMES, frame_number)
        
        # Read the frame at the current position
        success, frame = video_capture.read()
        
        if success:
            # Save the frame as a PNG file
            output_file = os.path.join(output_directory, f'frame_at_{frame_number // fps:.2f}_seconds.png')
            cv2.imwrite(output_file, frame)
            print(f'Successfully saved frame at {frame_number // fps:.2f} seconds to {output_file}')
            
            # Extract audio segment
            audio_output_file = os.path.join(output_directory, f'audio_at_{frame_number // fps:.2f}_seconds.wav')
            os.system(f'{ffmpeg_path} -loglevel error -i {video_path} -ss {frame_number // fps} -t {interval} -q:a 0 -map a {audio_output_file}')
            
            # Recognize the speech in the audio segment
            with sr.AudioFile(audio_output_file) as source:
                audio = recognizer.record(source)
                try:
                    transcription = recognizer.recognize_google(audio)
                    print(f'Transcription at {frame_number // fps:.2f} seconds: {transcription}')
                except sr.UnknownValueError:
                    print(f'Could not understand audio at {frame_number // fps:.2f} seconds')
                except sr.RequestError as e:
                    print(f'Could not request results from Google Speech Recognition service; {e}')

            # Save the results in json_results
            json_results.append({
                'timestamp': frame_number // fps,
                'frame': output_file,
                'audio': audio_output_file,
                'transcription': transcription if 'transcription' in locals() else None
            })
        else:
            print(f'Failed to capture frame at {frame_number // fps:.2f} seconds')
            
        # Move to the next frame interval
        frame_number += frame_interval
    
        # Define the output file path
        json_output_file = os.path.join(output_dir, 'json_results.json')

        # Save the json_results to the file
        with open(json_output_file, 'w') as f:
            json.dump(json_results, f, indent=4)


start_time = time.time()
# Capture frames and transcriptions every 3 secondsimport json
capture_frames_and_transcriptions(cap, video_path, output_dir, interval=x_interval)
end_time = time.time()

# Release the video capture object
cap.release()

print(f'Finished capturing frames and transcriptions every {x_interval} seconds in {end_time - start_time:.2f} seconds.')

# %%
# AWS Bedrock Claude price per 1,000 tokens for input and output tokens
model_price_list = {
    "haiku": {
        "input": 0.00025,
        "output": 0.00125,
        "input_batch": 0.000125,
        "output_batch": 0.000625,
    },
    "sonnet": {
        "input": 0.003,
        "output": 0.015,
        "input_batch": 0.0015,
        "output_batch": 0.0075,
    },
    "opus": {
        "input": 0.015,
        "output": 0.075,
        "input_batch": 0.0075,
        "output_batch": 0.0375,
    },
}

def calclulate_usage_and_cost(completion, price_list, image_frame):
    """
    calclulate_usage_and_cost calculates the cost of the completion.
    Calculate cost (for Claude 3). https://aws.amazon.com/bedrock/pricing/
    """
    
    models = ["haiku", "sonnet", "opus"]

    model_name = completion.model.lower()
    model = next((m for m in models if m in model_name), None)
    
    if model in models:
        usd_cost_per_k_input_tokens = price_list[model]["input"]
        usd_cost_per_k_output_tokens = price_list[model]["output"]
    else:
        print(f"Unknown model: {completion.model}, cannot calculate cost.")
        return
    
    usage_cost = {
        "image_frame": image_frame,
        "input_tokens": completion.usage.input_tokens,
        "output_tokens": completion.usage.output_tokens,
        "model": completion.model,
        "total_cost": round((completion.usage.input_tokens * usd_cost_per_k_input_tokens + completion.usage.output_tokens * usd_cost_per_k_output_tokens) / 1000, 6)
    }
    
    cost_input_tokens = (completion.usage.input_tokens * usd_cost_per_k_input_tokens) / 1000
    cost_output_tokens = (completion.usage.output_tokens * usd_cost_per_k_output_tokens) / 1000
    print(f"Input tokens  : {completion.usage.input_tokens}, cost: USD {round(cost_input_tokens, 6)}")
    print(f"Output tokens : {completion.usage.output_tokens}, cost: USD {round(cost_output_tokens, 6)}")
    print(f"LLM Model     : {completion.model}")
    print(f"Total cost    : USD {round(cost_input_tokens + cost_output_tokens, 6)} for this call.\n")
    
    return usage_cost

# # Test cases for the calclulate_usage_and_cost function
# class Completion:
#     def __init__(self, model, input_tokens, output_tokens):
#         self.model = model
#         self.usage = self.Usage(input_tokens, output_tokens)
    
#     class Usage:
#         def __init__(self, input_tokens, output_tokens):
#             self.input_tokens = input_tokens
#             self.output_tokens = output_tokens

# # Test case 1: Model haiku
# completion_haiku = Completion(model="haiku-123", input_tokens=1000, output_tokens=2000)
# calclulate_usage_and_cost(completion_haiku, model_price_list)

# # Test case 2: Model sonnet
# completion_sonnet = Completion(model="sonnet-456", input_tokens=1000, output_tokens=2000)
# calclulate_usage_and_cost(completion_sonnet, model_price_list)

# # Test case 3: Model opus
# completion_opus = Completion(model="opus-234", input_tokens=1000, output_tokens=2000)
# calclulate_usage_and_cost(completion_opus, model_price_list)

# # Test case 4: Unknown model
# completion_unknown = Completion(model="unknown", input_tokens=1000, output_tokens=2000)
# calclulate_usage_and_cost(completion_unknown, model_price_list)

# %%
import base64
from IPython.display import Image, display

def mermaid_graph(graph, scale=2):
    graphbytes = graph.encode("ascii")
    base64_bytes = base64.b64encode(graphbytes)
    base64_string = base64_bytes.decode("ascii")
    # print(base64_string)
    display(
        Image(
            url=f"https://mermaid.ink/img/{base64_string}"
        )
    )

mermaid_graph("""
graph LR;
    A[Start] --> B[Target Video - 165,000 tokens]

    subgraph "Step 1: Initial Extraction"
        B --> C1[Gemini Model Initial Prompt - 10,000 tokens]
        C1 --> D1{CSV Validation}
        D1 -->|Valid| E1[Output 1]
        D1 -->|Invalid| FX1[Gemini CSV Fixer Model]
        FX1 --> D1
    end

    subgraph "Step 2: Expand Extraction"
        B & E1 --> C2[Gemini Model Secondary Prompt - 2000-5000 tokens]
        C2 --> D2{CSV Validation}
        D2 -->|Valid| E2[Output 2]
        D2 -->|Invalid| FX2[Gemini CSV Fixer Model]
        FX2 --> D2
    end

    subgraph "Step 3: Finalize Extraction"
        B & E1 & E2 --> C3[Gemini Model Final Prompt - 2000-5000 tokens]
        C3 --> D3{CSV Validation}
        D3 -->|Valid| E3[Final Output]
        D3 -->|Invalid| FX3[Gemini CSV Fixer Model]
        FX3 --> D3
    end

    E3 --> F[Final Results]

    %% Styling
    style C1 fill:#b3d9ff,stroke:#333,stroke-width:1px
    style C2 fill:#b3d9ff,stroke:#333,stroke-width:1px
    style C3 fill:#b3d9ff,stroke:#333,stroke-width:1px
    style D1 fill:#f9f,stroke:#333,stroke-width:1px
    style D2 fill:#f9f,stroke:#333,stroke-width:1px
    style D3 fill:#f9f,stroke:#333,stroke-width:1px
    style FX1 fill:#ccffcc,stroke:#333,stroke-width:1px
    style FX2 fill:#ccffcc,stroke:#333,stroke-width:1px
    style FX3 fill:#ccffcc,stroke:#333,stroke-width:1px
""")

# %%
import os
import anthropic
import instructor
from dotenv import load_dotenv
import pandas as pd
import shutil

load_dotenv(verbose=True, dotenv_path=".env")

client = anthropic.AnthropicBedrock(
    aws_access_key=os.getenv("AWS_ACCESS_KEY_ID"),
    aws_secret_key=os.getenv("AWS_SECRET_ACCESS_KEY"),
    aws_session_token=os.getenv("AWS_SESSION_TOKEN"),
    aws_region=os.getenv("AWS_DEFAULT_REGION"),
)

# MODEL_ID = "anthropic.claude-3-haiku-20240307-v1:0"     # Claude 3 Haiku  
MODEL_ID = "anthropic.claude-3-sonnet-20240229-v1:0"    # Claude 3 Sonnet


# Regarding the LLM model choice, I would start with the cheapest option (Haiku). Depending on the tasks, the smallest 
# model might be sufficient. You will have to do some trial and error here. I found that the smallest model
# at times will have difficulty following certain instructions.
# For example, asking the LLM to summarise a body of text and constraining the summary say from minimum 100 and maximum 500 characters,
# the smallest model will sometimes fail to generate a summary that is within the character count constraints. In such cases,
# you might have to try a larger model.

instructor_client = instructor.from_anthropic(
    client,
    max_tokens=1000,
    model=MODEL_ID
)

# %%
from pydantic import BaseModel

# Define your desired output structure
class UserInfo(BaseModel):
    name: str
    age: int

user_info = instructor_client.chat.completions.create(
    response_model=UserInfo,
    messages=[{"role": "user", "content": "John Doe is 30 years old."}]
    )

print(user_info.name)
#> John Doe
print(user_info.age)
#> 30
# Out:
# John Doe
# 30

# %%
from typing import List
from pydantic import BaseModel, Field
from instructor.retry import InstructorRetryException
import warnings
import base64
import json

warnings.filterwarnings("ignore")

SYSTEM_PROMPT = """
You are an expert insurance agent who excels at cataloging all the items in a home based on images and voice transcriptions. The images and transcriptions
are extracted from a video every 3 seconds.  The purpose of this task is to automate the process of cataloging items for contents insurance. Do not
include parts of the home itself, only items that would be covered by insurance. It is importatnt to count the number of items accurately and mention the count,
color, size, and brand if visible, in the item description. Include everything visible, including items in the foreground and background.

For each room in the house, identify and list all the items you can find in this image.
"""
# Return the list in JSON format as:
# {
#     "catalog_items": [
#         {"item_number": 1, "item_name": "sofa", "item_description": "red three seater sofa"},
#         {"item_number": 2, "item_name": "LCD TV", "item_description": "Samsung 55 inch smart TV"},
#         {"item_number": 3, "item_name": "Dishwasher", "item_description": "Bosch 12 place setting dishwasher"}
#     ]
# }


class CatalogItem(BaseModel):
    """
    Response model for a catalog item.
    """
    item_no: int = Field(..., description="The sequential number of the catalog item.")
    item_name: str = Field(..., description="A name for this catalog item.")
    item_desc: str = Field(..., description="A short description of this catalog item.")
    room_loc: str = Field(..., description="The room location in the house of this catalog item.")

class CatalogItems(BaseModel):
    """
    Response model for a list of catalog items.
    """
    items: List[CatalogItem] = Field(..., description="A list of catalog items in a house.")

class HomeCatalogger:
    """
    Catalog all the items in a home based on the images and voice transcriptions provided.
    """

    def __init__(self, client):
        self.client = client

    def catalog(self, image_path: str) -> CatalogItems:
        try:
            with open(image_path, "rb") as image_file:
                image_data = base64.b64encode(image_file.read()).decode("utf-8")

            catalog, completion = self.client.chat.completions.create_with_completion(
                messages=[
                    {"role": "user",
                        "content": [
                            {
                                "type": "image",
                                "source": {
                                    "type": "base64",
                                    "media_type": "image/png",
                                    "data": image_data
                                }
                            },
                            {
                                "type": "text",
                                "text": f"This is the image frame: {image_path}"
                            }
                        ]
                    }
                ],
                system=SYSTEM_PROMPT,
                response_model=CatalogItems,
                temperature=0.0,
                max_retries=1,
            )

            # print(f"LLM Catalogging...")
            # print(catalog.model_dump_json(indent=2))
            # print()
            cost = calclulate_usage_and_cost(completion, model_price_list, os.path.basename(image_path))
            # print()
            return catalog, cost

        except InstructorRetryException as e:
            print(e)
            print(f"Retries attempted: {e.n_attempts}")
            print(e.last_completion)


# Initialize the HomeCatalogger with the instructor client
home_catalogger = HomeCatalogger(instructor_client)

# Load the JSON results
with open("./frames/json_results.json", "r") as file:
    json_results = json.load(file)

# Extract the first x image frames
image_frames = [item["frame"] for item in json_results[:30] ]

catalog_items = []
llm_costs = []
# Iterate through the image frames and pass each image to the catalogger
for frame in image_frames:
    print(f"Cataloging items in image: {frame}")
    catalog, cost = home_catalogger.catalog(frame)
    catalog_items.extend(catalog.items)
    llm_costs.append(cost)

# # Path to an example image
# output_dir = "frames" # re-declaring here... you can do it once at the top
# example_image_path = os.path.join(output_dir, "frame_at_63.00_seconds.png")

# # Catalog the items in the example image
# catalog_items = home_catalogger.catalog(example_image_path)

# Print the cataloged items
print(catalog_items)
print(llm_costs)
# Out:
# Cataloging items in image: frames/frame_at_0.00_seconds.png
# Input tokens  : 1939, cost: USD 0.005817
# Output tokens : 90, cost: USD 0.00135
# LLM Model     : claude-3-sonnet-20240229
# Total cost    : USD 0.007167 for this call.
#
# Cataloging items in image: frames/frame_at_3.00_seconds.png
# Input tokens  : 1939, cost: USD 0.005817
# Output tokens : 227, cost: USD 0.003405
# LLM Model     : claude-3-sonnet-20240229
# Total cost    : USD 0.009222 for this call.
#
# Cataloging items in image: frames/frame_at_6.00_seconds.png
# Input tokens  : 1939, cost: USD 0.005817
# Output tokens : 446, cost: USD 0.00669
# LLM Model     : claude-3-sonnet-20240229
# Total cost    : USD 0.012507 for this call.
#
# Cataloging items in image: frames/frame_at_9.00_seconds.png
# Input tokens  : 1939, cost: USD 0.005817
# Output tokens : 505, cost: USD 0.007575
# LLM Model     : claude-3-sonnet-20240229
# Total cost    : USD 0.013392 for this call.
#
# Cataloging items in image: frames/frame_at_12.00_seconds.png
# Input tokens  : 1939, cost: USD 0.005817
# Output tokens : 340, cost: USD 0.0051
# LLM Model     : claude-3-sonnet-20240229
# Total cost    : USD 0.010917 for this call.
#
# Cataloging items in image: frames/frame_at_15.00_seconds.png
# Input tokens  : 1939, cost: USD 0.005817
# Output tokens : 348, cost: USD 0.00522
# LLM Model     : claude-3-sonnet-20240229
# Total cost    : USD 0.011037 for this call.
#
# Cataloging items in image: frames/frame_at_18.00_seconds.png
# Input tokens  : 1939, cost: USD 0.005817
# Output tokens : 345, cost: USD 0.005175
# LLM Model     : claude-3-sonnet-20240229
# Total cost    : USD 0.010992 for this call.
#
# Cataloging items in image: frames/frame_at_21.00_seconds.png
# Input tokens  : 1939, cost: USD 0.005817
# Output tokens : 299, cost: USD 0.004485
# LLM Model     : claude-3-sonnet-20240229
# Total cost    : USD 0.010302 for this call.
#
# Cataloging items in image: frames/frame_at_24.00_seconds.png
# Input tokens  : 1939, cost: USD 0.005817
# Output tokens : 265, cost: USD 0.003975
# LLM Model     : claude-3-sonnet-20240229
# Total cost    : USD 0.009792 for this call.
#
# Cataloging items in image: frames/frame_at_27.00_seconds.png
# Input tokens  : 1939, cost: USD 0.005817
# Output tokens : 232, cost: USD 0.00348
# LLM Model     : claude-3-sonnet-20240229
# Total cost    : USD 0.009297 for this call.
#
# Cataloging items in image: frames/frame_at_30.00_seconds.png
# Input tokens  : 1939, cost: USD 0.005817
# Output tokens : 203, cost: USD 0.003045
# LLM Model     : claude-3-sonnet-20240229
# Total cost    : USD 0.008862 for this call.
#
# Cataloging items in image: frames/frame_at_33.00_seconds.png
# Input tokens  : 1939, cost: USD 0.005817
# Output tokens : 277, cost: USD 0.004155
# LLM Model     : claude-3-sonnet-20240229
# Total cost    : USD 0.009972 for this call.
#
# Cataloging items in image: frames/frame_at_36.00_seconds.png
# Input tokens  : 1939, cost: USD 0.005817
# Output tokens : 391, cost: USD 0.005865
# LLM Model     : claude-3-sonnet-20240229
# Total cost    : USD 0.011682 for this call.
#
# Cataloging items in image: frames/frame_at_39.00_seconds.png
# Input tokens  : 1939, cost: USD 0.005817
# Output tokens : 246, cost: USD 0.00369
# LLM Model     : claude-3-sonnet-20240229
# Total cost    : USD 0.009507 for this call.
#
# Cataloging items in image: frames/frame_at_42.00_seconds.png
# Input tokens  : 1939, cost: USD 0.005817
# Output tokens : 285, cost: USD 0.004275
# LLM Model     : claude-3-sonnet-20240229
# Total cost    : USD 0.010092 for this call.
#
# Cataloging items in image: frames/frame_at_45.00_seconds.png
# Input tokens  : 1939, cost: USD 0.005817
# Output tokens : 153, cost: USD 0.002295
# LLM Model     : claude-3-sonnet-20240229
# Total cost    : USD 0.008112 for this call.
#
# Cataloging items in image: frames/frame_at_48.00_seconds.png
# Input tokens  : 1939, cost: USD 0.005817
# Output tokens : 229, cost: USD 0.003435
# LLM Model     : claude-3-sonnet-20240229
# Total cost    : USD 0.009252 for this call.
#
# Cataloging items in image: frames/frame_at_51.00_seconds.png
# Input tokens  : 1939, cost: USD 0.005817
# Output tokens : 291, cost: USD 0.004365
# LLM Model     : claude-3-sonnet-20240229
# Total cost    : USD 0.010182 for this call.
#
# Cataloging items in image: frames/frame_at_54.00_seconds.png
# Input tokens  : 1939, cost: USD 0.005817
# Output tokens : 245, cost: USD 0.003675
# LLM Model     : claude-3-sonnet-20240229
# Total cost    : USD 0.009492 for this call.
#
# Cataloging items in image: frames/frame_at_57.00_seconds.png
# Input tokens  : 1939, cost: USD 0.005817
# Output tokens : 148, cost: USD 0.00222
# LLM Model     : claude-3-sonnet-20240229
# Total cost    : USD 0.008037 for this call.
#
# Cataloging items in image: frames/frame_at_60.00_seconds.png
# Input tokens  : 1939, cost: USD 0.005817
# Output tokens : 477, cost: USD 0.007155
# LLM Model     : claude-3-sonnet-20240229
# Total cost    : USD 0.012972 for this call.
#
# Cataloging items in image: frames/frame_at_63.00_seconds.png
# Input tokens  : 1939, cost: USD 0.005817
# Output tokens : 225, cost: USD 0.003375
# LLM Model     : claude-3-sonnet-20240229
# Total cost    : USD 0.009192 for this call.
#
# Cataloging items in image: frames/frame_at_66.00_seconds.png
# Input tokens  : 1939, cost: USD 0.005817
# Output tokens : 344, cost: USD 0.00516
# LLM Model     : claude-3-sonnet-20240229
# Total cost    : USD 0.010977 for this call.
#
# Cataloging items in image: frames/frame_at_69.00_seconds.png
# Input tokens  : 1939, cost: USD 0.005817
# Output tokens : 274, cost: USD 0.00411
# LLM Model     : claude-3-sonnet-20240229
# Total cost    : USD 0.009927 for this call.
#
# Cataloging items in image: frames/frame_at_72.00_seconds.png
# Input tokens  : 1939, cost: USD 0.005817
# Output tokens : 298, cost: USD 0.00447
# LLM Model     : claude-3-sonnet-20240229
# Total cost    : USD 0.010287 for this call.
#
# Cataloging items in image: frames/frame_at_75.00_seconds.png
# Input tokens  : 1939, cost: USD 0.005817
# Output tokens : 269, cost: USD 0.004035
# LLM Model     : claude-3-sonnet-20240229
# Total cost    : USD 0.009852 for this call.
#
# Cataloging items in image: frames/frame_at_78.00_seconds.png
# Input tokens  : 1939, cost: USD 0.005817
# Output tokens : 323, cost: USD 0.004845
# LLM Model     : claude-3-sonnet-20240229
# Total cost    : USD 0.010662 for this call.
#
# Cataloging items in image: frames/frame_at_81.00_seconds.png
# Input tokens  : 1939, cost: USD 0.005817
# Output tokens : 152, cost: USD 0.00228
# LLM Model     : claude-3-sonnet-20240229
# Total cost    : USD 0.008097 for this call.
#
# Cataloging items in image: frames/frame_at_84.00_seconds.png
# Input tokens  : 1939, cost: USD 0.005817
# Output tokens : 91, cost: USD 0.001365
# LLM Model     : claude-3-sonnet-20240229
# Total cost    : USD 0.007182 for this call.
#
# Cataloging items in image: frames/frame_at_87.00_seconds.png
# Input tokens  : 1939, cost: USD 0.005817
# Output tokens : 279, cost: USD 0.004185
# LLM Model     : claude-3-sonnet-20240229
# Total cost    : USD 0.010002 for this call.
#
# [CatalogItem(item_no=1, item_name='Sofa', item_desc='1 tan colored fabric sofa visible in the hallway', room_loc='Hallway'), CatalogItem(item_no=1, item_name='Sofa', item_desc='A large beige sectional sofa with brown and tan throw pillows, appears to be made of fabric', room_loc='Living room'), CatalogItem(item_no=2, item_name='Ceiling fan', item_desc='A ceiling mounted fan with multiple blades, likely metal', room_loc='Living room'), CatalogItem(item_no=3, item_name='Light fixtures', item_desc='Multiple recessed light fixtures in the ceiling, likely LED or halogen bulbs', room_loc='Living room'), CatalogItem(item_no=1, item_name='Sofa', item_desc='A large white fabric sofa, seating 3-4 people', room_loc='Living room'), CatalogItem(item_no=2, item_name='Armchairs', item_desc='Two green upholstered armchairs', room_loc='Living room'), CatalogItem(item_no=3, item_name='Coffee table', item_desc='A rectangular wooden coffee table with a glass top', room_loc='Living room'), CatalogItem(item_no=4, item_name='TV stand', item_desc='A low wooden TV stand or media console', room_loc='Living room'), CatalogItem(item_no=5, item_name='Artwork', item_desc='A large abstract artwork hanging on the wall', room_loc='Living room'), CatalogItem(item_no=6, item_name='Decorative vase', item_desc='A tall decorative vase on the coffee table', room_loc='Living room'), CatalogItem(item_no=7, item_name='Throw pillows', item_desc='Several decorative throw pillows on the sofa, brown and yellow colors', room_loc='Living room'), CatalogItem(item_no=1, item_name='Sofa', item_desc='A large light gray sectional sofa', room_loc='Living room'), CatalogItem(item_no=2, item_name='Coffee table', item_desc='A rectangular light wood coffee table with a glass top', room_loc='Living room'), CatalogItem(item_no=3, item_name='Armchairs', item_desc='Two olive green upholstered armchairs', room_loc='Living room'), CatalogItem(item_no=4, item_name='Side table', item_desc='A small round light wood side table', room_loc='Living room'), CatalogItem(item_no=5, item_name='Decor items', item_desc='A vase, a lamp, and a few small decorative items on the side table', room_loc='Living room'), CatalogItem(item_no=6, item_name='Wall art', item_desc='A large abstract wall hanging with brown and beige stripes', room_loc='Living room'), CatalogItem(item_no=7, item_name='TV stand', item_desc='A low light wood TV stand or media console', room_loc='Living room'), CatalogItem(item_no=8, item_name='Throw pillows', item_desc='Several brown and yellow decorative throw pillows on the sofa', room_loc='Living room'), CatalogItem(item_no=1, item_name='Wooden coffee table', item_desc='A large rectangular wooden coffee table in the center of the room', room_loc='Living room'), CatalogItem(item_no=2, item_name='Sofa', item_desc='A large white fabric sofa with yellow and brown patterned cushions', room_loc='Living room'), CatalogItem(item_no=3, item_name='Decorative vase', item_desc='A small green glass decorative vase on the coffee table', room_loc='Living room'), CatalogItem(item_no=4, item_name='Decorative figurine', item_desc='A small brown decorative figurine on the coffee table', room_loc='Living room'), CatalogItem(item_no=5, item_name='TV stand', item_desc='A long wooden TV stand against the wall with shelves', room_loc='Living room'), CatalogItem(item_no=1, item_name='Plush toy', item_desc='A small yellow plush toy in the shape of a bird, sitting on a wooden cabinet', room_loc='Living room'), CatalogItem(item_no=2, item_name='Wooden cabinet', item_desc='A light wood cabinet with shelves and drawers for storage, located against the wall', room_loc='Living room'), CatalogItem(item_no=3, item_name='Potted plant', item_desc='A large green potted plant next to the wooden cabinet', room_loc='Living room'), CatalogItem(item_no=4, item_name='Armchair', item_desc='A large green upholstered armchair in the center of the room', room_loc='Living room'), CatalogItem(item_no=5, item_name='Coffee table', ite ...
# [{'image_frame': 'frame_at_0.00_seconds.png', 'input_tokens': 1939, 'output_tokens': 90, 'model': 'claude-3-sonnet-20240229', 'total_cost': 0.007167}, {'image_frame': 'frame_at_3.00_seconds.png', 'input_tokens': 1939, 'output_tokens': 227, 'model': 'claude-3-sonnet-20240229', 'total_cost': 0.009222}, {'image_frame': 'frame_at_6.00_seconds.png', 'input_tokens': 1939, 'output_tokens': 446, 'model': 'claude-3-sonnet-20240229', 'total_cost': 0.012507}, {'image_frame': 'frame_at_9.00_seconds.png', 'input_tokens': 1939, 'output_tokens': 505, 'model': 'claude-3-sonnet-20240229', 'total_cost': 0.013392}, {'image_frame': 'frame_at_12.00_seconds.png', 'input_tokens': 1939, 'output_tokens': 340, 'model': 'claude-3-sonnet-20240229', 'total_cost': 0.010917}, {'image_frame': 'frame_at_15.00_seconds.png', 'input_tokens': 1939, 'output_tokens': 348, 'model': 'claude-3-sonnet-20240229', 'total_cost': 0.011037}, {'image_frame': 'frame_at_18.00_seconds.png', 'input_tokens': 1939, 'output_tokens': 345, 'model': 'claude-3-sonnet-20240229', 'total_cost': 0.010992}, {'image_frame': 'frame_at_21.00_seconds.png', 'input_tokens': 1939, 'output_tokens': 299, 'model': 'claude-3-sonnet-20240229', 'total_cost': 0.010302}, {'image_frame': 'frame_at_24.00_seconds.png', 'input_tokens': 1939, 'output_tokens': 265, 'model': 'claude-3-sonnet-20240229', 'total_cost': 0.009792}, {'image_frame': 'frame_at_27.00_seconds.png', 'input_tokens': 1939, 'output_tokens': 232, 'model': 'claude-3-sonnet-20240229', 'total_cost': 0.009297}, {'image_frame': 'frame_at_30.00_seconds.png', 'input_tokens': 1939, 'output_tokens': 203, 'model': 'claude-3-sonnet-20240229', 'total_cost': 0.008862}, {'image_frame': 'frame_at_33.00_seconds.png', 'input_tokens': 1939, 'output_tokens': 277, 'model': 'claude-3-sonnet-20240229', 'total_cost': 0.009972}, {'image_frame': 'frame_at_36.00_seconds.png', 'input_tokens': 1939, 'output_tokens': 391, 'model': 'claude-3-sonnet-20240229', 'total_cost': 0.011682}, {'image_frame': 'frame_at_39.00_seconds.png', 'input_tokens': 1939, 'output_tokens': 246, 'model': 'claude-3-sonnet-20240229', 'total_cost': 0.009507}, {'image_frame': 'frame_at_42.00_seconds.png', 'input_tokens': 1939, 'output_tokens': 285, 'model': 'claude-3-sonnet-20240229', 'total_cost': 0.010092}, {'image_frame': 'frame_at_45.00_seconds.png', 'input_tokens': 1939, 'output_tokens': 153, 'model': 'claude-3-sonnet-20240229', 'total_cost': 0.008112}, {'image_frame': 'frame_at_48.00_seconds.png', 'input_tokens': 1939, 'output_tokens': 229, 'model': 'claude-3-sonnet-20240229', 'total_cost': 0.009252}, {'image_frame': 'frame_at_51.00_seconds.png', 'input_tokens': 1939, 'output_tokens': 291, 'model': 'claude-3-sonnet-20240229', 'total_cost': 0.010182}, {'image_frame': 'frame_at_54.00_seconds.png', 'input_tokens': 1939, 'output_tokens': 245, 'model': 'claude-3-sonnet-20240229', 'total_cost': 0.009492}, {'image_frame': 'frame_at_57.00_seconds.png', 'input_tokens': 1939, 'output_tokens': 148, 'model': 'claude-3-sonnet-20240229', 'total_cost': 0.008037}, {'image_frame': 'frame_at_60.00_seconds.png', 'input_tokens': 1939, 'output_tokens': 477, 'model': 'claude-3-sonnet-20240229', 'total_cost': 0.012972}, {'image_frame': 'frame_at_63.00_seconds.png', 'input_tokens': 1939, 'output_tokens': 225, 'model': 'claude-3-sonnet-20240229', 'total_cost': 0.009192}, {'image_frame': 'frame_at_66.00_seconds.png', 'input_tokens': 1939, 'output_tokens': 344, 'model': 'claude-3-sonnet-20240229', 'total_cost': 0.010977}, {'image_frame': 'frame_at_69.00_seconds.png', 'input_tokens': 1939, 'output_tokens': 274, 'model': 'claude-3-sonnet-20240229', 'total_cost': 0.009927}, {'image_frame': 'frame_at_72.00_seconds.png', 'input_tokens': 1939, 'output_tokens': 298, 'model': 'claude-3-sonnet-20240229', 'total_cost': 0.010287}, {'image_frame': 'frame_at_75.00_seconds.png', 'input_tokens': 1939, 'output_tokens': 269, 'model': 'claude-3-sonnet-20240229', 'total_cost': 0.009852}, {'image_frame': 'frame_at_78.00_seconds.png', 'input ...

# %%
# Fix item numbers to be sequential
for idx, item in enumerate(catalog_items, start=1):
    item.item_no = idx

for item in catalog_items:
    # print(f"Frame {item.}, Item {item.item_no}: {item.item_name} - {item.item_desc}")
    print(item)
    
total_input_tokens = sum(cost['input_tokens'] for cost in llm_costs)
total_output_tokens = sum(cost['output_tokens'] for cost in llm_costs)
total_cost_usd = sum(cost['total_cost'] for cost in llm_costs)

print()
print(f"Total input tokens: {total_input_tokens}")
print(f"Total output tokens: {total_output_tokens}")
print(f"Total cost in USD: {total_cost_usd:.6f}")
# Out:
# item_no=1 item_name='Sofa' item_desc='1 tan colored fabric sofa visible in the hallway' room_loc='Hallway'
# item_no=2 item_name='Sofa' item_desc='A large beige sectional sofa with brown and tan throw pillows, appears to be made of fabric' room_loc='Living room'
# item_no=3 item_name='Ceiling fan' item_desc='A ceiling mounted fan with multiple blades, likely metal' room_loc='Living room'
# item_no=4 item_name='Light fixtures' item_desc='Multiple recessed light fixtures in the ceiling, likely LED or halogen bulbs' room_loc='Living room'
# item_no=5 item_name='Sofa' item_desc='A large white fabric sofa, seating 3-4 people' room_loc='Living room'
# item_no=6 item_name='Armchairs' item_desc='Two green upholstered armchairs' room_loc='Living room'
# item_no=7 item_name='Coffee table' item_desc='A rectangular wooden coffee table with a glass top' room_loc='Living room'
# item_no=8 item_name='TV stand' item_desc='A low wooden TV stand or media console' room_loc='Living room'
# item_no=9 item_name='Artwork' item_desc='A large abstract artwork hanging on the wall' room_loc='Living room'
# item_no=10 item_name='Decorative vase' item_desc='A tall decorative vase on the coffee table' room_loc='Living room'
# item_no=11 item_name='Throw pillows' item_desc='Several decorative throw pillows on the sofa, brown and yellow colors' room_loc='Living room'
# item_no=12 item_name='Sofa' item_desc='A large light gray sectional sofa' room_loc='Living room'
# item_no=13 item_name='Coffee table' item_desc='A rectangular light wood coffee table with a glass top' room_loc='Living room'
# item_no=14 item_name='Armchairs' item_desc='Two olive green upholstered armchairs' room_loc='Living room'
# item_no=15 item_name='Side table' item_desc='A small round light wood side table' room_loc='Living room'
# item_no=16 item_name='Decor items' item_desc='A vase, a lamp, and a few small decorative items on the side table' room_loc='Living room'
# item_no=17 item_name='Wall art' item_desc='A large abstract wall hanging with brown and beige stripes' room_loc='Living room'
# item_no=18 item_name='TV stand' item_desc='A low light wood TV stand or media console' room_loc='Living room'
# item_no=19 item_name='Throw pillows' item_desc='Several brown and yellow decorative throw pillows on the sofa' room_loc='Living room'
# item_no=20 item_name='Wooden coffee table' item_desc='A large rectangular wooden coffee table in the center of the room' room_loc='Living room'
# item_no=21 item_name='Sofa' item_desc='A large white fabric sofa with yellow and brown patterned cushions' room_loc='Living room'
# item_no=22 item_name='Decorative vase' item_desc='A small green glass decorative vase on the coffee table' room_loc='Living room'
# item_no=23 item_name='Decorative figurine' item_desc='A small brown decorative figurine on the coffee table' room_loc='Living room'
# item_no=24 item_name='TV stand' item_desc='A long wooden TV stand against the wall with shelves' room_loc='Living room'
# item_no=25 item_name='Plush toy' item_desc='A small yellow plush toy in the shape of a bird, sitting on a wooden cabinet' room_loc='Living room'
# item_no=26 item_name='Wooden cabinet' item_desc='A light wood cabinet with shelves and drawers for storage, located against the wall' room_loc='Living room'
# item_no=27 item_name='Potted plant' item_desc='A large green potted plant next to the wooden cabinet' room_loc='Living room'
# item_no=28 item_name='Armchair' item_desc='A large green upholstered armchair in the center of the room' room_loc='Living room'
# item_no=29 item_name='Coffee table' item_desc='A light wood coffee table in front of the armchair' room_loc='Living room'
# item_no=30 item_name='Framed artwork' item_desc='A large framed abstract artwork with pink and brown stripes' room_loc='Living room'
# item_no=31 item_name='Decorative pumpkins' item_desc='Two small decorative yellow pumpkins' room_loc='Living room'
# item_no=32 item_name='TV stand' item_desc='A long wooden TV stand or media console' room_loc='Living room'
# item_no=33 item_name='Potted plant' item_desc='A tall potted plant or faux plant' room_loc='Living room'
# item_no=34 item_name='Armchairs' item_desc='Two large olive green armchairs or sofas' room_loc='Living room'
# item_no=35 item_name='Coffee table' item_desc='A round glass-top coffee table' room_loc='Living room'
# item_no=36 item_name='Abstract painting' item_desc='A large abstract painting with brown, tan and gray geometric patterns' room_loc='Living room'
# item_no=37 item_name='Floor lamp' item_desc='A tall arched metal floor lamp with a single light bulb' room_loc='Living room'
# item_no=38 item_name='Potted plant' item_desc='A small potted plant with green leaves' room_loc='Living room'
# item_no=39 item_name='Cabinet' item_desc='A low wooden cabinet or sideboard with closed doors' room_loc='Living room'
# item_no=40 item_name='Decorative pumpkin' item_desc='A small golden decorative pumpkin figurine' room_loc='Living room'
# item_no=41 item_name='Wall mirror' item_desc='A large arched black metal framed wall mirror' room_loc='Living room'
# item_no=42 item_name='Potted plant' item_desc='A small potted plant with green leaves' room_loc='Living room'
# item_no=43 item_name='Wooden bench' item_desc='A light brown wooden bench or entryway table' room_loc='Living room'
# item_no=44 item_name='Wall art' item_desc='A framed wall art or picture hanging on the wall' room_loc='Living room'
# item_no=45 item_name='Curtains' item_desc='White sheer curtains covering a window' room_loc='Living room'
# item_no=46 item_name='Lamp' item_desc='Small table lamp on a side table' room_loc='Living room'
# item_no=47 item_name='Plant' item_desc='Small potted plant, likely artificial' room_loc='Living room'
# item_no=48 item_name='Artwork' item_desc='Framed artwork or picture hanging on the wall' room_loc='Living room'
# item_no=49 item_name='Server rack' item_desc='A large black metal server rack with multiple shelves holding computer equipment and cables' room_loc='Server room'
# item_no=50 item_name='Office chair' item_desc='A green ergonomic office chair on wheels' room_loc='Server room'
# item_no=51 item_name='Networking equipment' item_desc='Various black networking devices like routers, switches, and modems on the server rack shelves' room_loc='Server room'
# item_no=52 item_name='Broom' item_desc='An orange plastic broom for cleaning' room_loc='Utility room'
# item_no=53 item_name='Cleaning supplies' item_desc='Various bottles and containers of cleaning products on shelves, approximately 10 items' room_loc='Utility room'
# item_no=54 item_name='Storage bins' item_desc='Several plastic storage bins on shelves, around 5 bins' room_loc='Utility room'
# item_no=55 item_name='Mop' item_desc='A blue mop handle visible leaning against shelves' room_loc='Utility room'
# item_no=56 item_name='Mop' item_desc='An orange plastic mop for cleaning floors' room_loc='Utility room'
# item_no=57 item_name='Cleaning supplies' item_desc='Multiple yellow bottles of cleaning solution, likely a brand like Fabuloso' room_loc='Utility room'
# item_no=58 item_name='Sponges' item_desc='Orange sponges for cleaning surfaces' room_loc='Utility room'
# item_no=59 item_name='Cleaning rags' item_desc='Blue and white rags or towels for cleaning' room_loc='Utility room'
# item_no=60 item_name='Brooms' item_desc='Multiple blue and purple brooms or brushes for cleaning' room_loc='Utility room'
# item_no=61 item_name='Storage shelves' item_desc='White metal shelving units for storing cleaning supplies' room_loc='Utility room'
# item_no=62 item_name='Server rack' item_desc="A large metal rack with multiple shelves holding computer servers and networking equipment, including black server towers, beige server towers labeled 'One', and yellow network switches." room_loc='Server room'
# item_no=63 item_name='UPS battery backup' item_desc='An orange uninterruptible power supply (UPS) battery backup unit on the bottom shelf.' room_loc='Server room'
# item_no=64 item_name='Liquid container' item_desc='A white plastic liquid container, likely for cooling or cleaning the server equipment.' room_loc='Server room'
# item_no=65 item_name='Books' item_desc='Multiple black and yellow books, likely textbooks or reference books, stacked on a shelf.' room_loc='Office or Study Room'
# item_no=66 item_name='Computer Speakers' item_desc='A pair of black computer speakers visible on the shelf.' room_loc='Office or Study Room'
# item_no=67 item_name='Tablet or E-Reader' item_desc='An orange tablet or e-reader device on the desk.' room_loc='Office or Study Room'
# item_no=68 item_name='Cleaning Supplies' item_desc='A bottle of cleaning solution visible on the desk.' room_loc='Office or Study Room'
# item_no=69 item_name='Books' item_desc="Approximately 30 copies of the book titled 'Charlie Walks' by Daniel Rooney, in black and yellow covers." room_loc='Office'
# item_no=70 item_name='Stapler' item_desc='1 orange and black Sandsbury stapler' room_loc='Office'
# item_no=71 item_name='Life jacket' item_desc='An orange life jacket' room_loc='Garage'
# item_no=72 item_name='Shelving units' item_desc='Several white metal shelving units' room_loc='Garage'
# item_no=73 item_name='Storage bins' item_desc='Multiple yellow and black plastic storage bins on shelves' room_loc='Garage'
# item_no=74 item_name='Extension cords' item_desc='Orange and black extension cords' room_loc='Garage'
# item_no=75 item_name='Broom' item_desc='1 orange plastic broom' room_loc='Utility room'
# item_no=76 item_name='Mop' item_desc='1 orange plastic mop' room_loc='Utility room'
# item_no=77 item_name='Cleaning supplies' item_desc='Multiple bottles and containers of various cleaning supplies on shelves' room_loc='Utility room'
# item_no=78 item_name='Storage bins' item_desc='Several black plastic storage bins on shelves' room_loc='Utility room'
# item_no=79 item_name='Shelving unit' item_desc='1 white metal shelving unit holding various items' room_loc='Utility room'
# item_no=80 item_name='Sofa' item_desc='A large beige sectional sofa with multiple cushions' room_loc='Living room'
# item_no=81 item_name='Armchair' item_desc='A green upholstered armchair' room_loc='Living room'
# item_no=82 item_name='Coffee table' item_desc='A wooden coffee table with a glass top' room_loc='Living room'
# item_no=83 item_name='Throw pillows' item_desc='Multiple yellow and green decorative throw pillows on the sofa' room_loc='Living room'
# item_no=84 item_name='Sunglasses' item_desc='A pair of black sunglasses on the floor' room_loc='Kitchen'
# item_no=85 item_name='Kitchen Appliances' item_desc='Multiple stainless steel kitchen appliances including an oven and microwave visible through the window' room_loc='Kitchen'
# item_no=86 item_name='Refrigerator' item_desc='A stainless steel side-by-side refrigerator, approximately 6 feet tall' room_loc='Kitchen'
# item_no=87 item_name='Kitchen cabinets' item_desc='A set of dark brown wooden cabinets lining the kitchen walls, with approximately 10 cabinet doors visible' room_loc='Kitchen'
# item_no=88 item_name='Countertop' item_desc='A long light-colored stone countertop spanning the length of the kitchen' room_loc='Kitchen'
# item_no=89 item_name='Vase' item_desc='A small ceramic vase with dried flowers on the countertop' room_loc='Kitchen'
# item_no=90 item_name='Fruit bowl' item_desc='A woven basket with red apples or tomatoes on the countertop' room_loc='Kitchen'
# item_no=91 item_name='Magazines' item_desc='Two magazines or catalogs lying open on the countertop' room_loc='Kitchen'
# item_no=92 item_name='Chair' item_desc='A black leather chair or stool visible in the corner of the kitchen' room_loc='Kitchen'
# item_no=93 item_name='Dining table' item_desc='A large rectangular wooden dining table with 6 brown upholstered chairs around it' room_loc='Dining room'
# item_no=94 item_name='Stuffed animal' item_desc='A small white stuffed animal figure on the dining table' room_loc='Dining room'
# item_no=95 item_name='Stools' item_desc='2 small wooden stools or side tables near the dining table' room_loc='Dining room'
# item_no=96 item_name='Kitchen Counter' item_desc='A long white kitchen counter with black cabinets underneath' room_loc='Kitchen'
# item_no=97 item_name='Fruit Bowl' item_desc='A wooden bowl containing several red apples' room_loc='Kitchen'
# item_no=98 item_name='Cutting Board' item_desc='A wooden cutting board with some bread or pastries on it' room_loc='Kitchen'
# item_no=99 item_name='Stools' item_desc='3 wooden stools with metal legs' room_loc='Kitchen'
# item_no=100 item_name='Dining Table' item_desc='A large wooden dining table with grey upholstered chairs' room_loc='Kitchen'
# item_no=101 item_name='Decor Items' item_desc='Several decorative items like vases and plants on the counter' room_loc='Kitchen'
# item_no=102 item_name='Wooden dining table' item_desc='A large rectangular wooden dining table with carved designs on the surface, seating 6 people' room_loc='Dining room'
# item_no=103 item_name='Dining chairs' item_desc='6 brown leather upholstered dining chairs surrounding the table' room_loc='Dining room'
# item_no=104 item_name='Decorative figurine' item_desc='A small white decorative figurine in the shape of a person on the dining table' room_loc='Dining room'
# item_no=105 item_name='Potted plant' item_desc='A medium sized potted plant with green leaves on the dining table' room_loc='Dining room'
# item_no=106 item_name='Dining table' item_desc='1 large wooden dining table' room_loc='Dining room'
# item_no=107 item_name='Dining chairs' item_desc='4 tan upholstered dining chairs' room_loc='Dining room'
# item_no=108 item_name='Potted plant' item_desc='1 small potted plant in a white planter' room_loc='Dining room'
# item_no=109 item_name='Outdoor chairs' item_desc='2 white outdoor chairs visible through sliding glass door' room_loc='Patio'
# item_no=110 item_name='Outdoor table' item_desc='1 small outdoor table visible through sliding glass door' room_loc='Patio'
# item_no=111 item_name='Dining table' item_desc='A large wooden dining table with 6 brown leather chairs around it.' room_loc='Kitchen/Dining Room'
# item_no=112 item_name='Vase' item_desc='A clear glass vase on the dining table.' room_loc='Kitchen/Dining Room'
# item_no=113 item_name='Kitchen appliances' item_desc='Multiple stainless steel kitchen appliances including an oven and microwave visible in the background.' room_loc='Kitchen/Dining Room'
# item_no=114 item_name='Potted plant' item_desc='A small potted plant on a side table or counter.' room_loc='Kitchen/Dining Room'
# item_no=115 item_name='Refrigerator' item_desc='A large stainless steel side-by-side refrigerator, likely a high-end brand' room_loc='Kitchen'
# item_no=116 item_name='Kitchen Cabinets' item_desc='A set of dark wood kitchen cabinets with multiple drawers and doors' room_loc='Kitchen'
# item_no=117 item_name='Oven/Stove' item_desc='A built-in stainless steel oven and stovetop unit' room_loc='Kitchen'
# item_no=118 item_name='Sofa' item_desc='A grey sofa visible in the background living room area' room_loc='Living Room'
# item_no=119 item_name='Decor Items' item_desc='A few small decorative items on the kitchen counters' room_loc='Kitchen'
# item_no=120 item_name='Kitchen Cabinets' item_desc='Multiple wooden kitchen cabinets, color appears to be dark brown or black' room_loc='Kitchen'
# item_no=121 item_name='Kitchen Countertop' item_desc='A large kitchen countertop, color appears to be light tan or beige' room_loc='Kitchen'
# item_no=122 item_name='Dishwasher' item_desc='A stainless steel Miele brand dishwasher' room_loc='Kitchen'
# item_no=123 item_name='Microwave oven' item_desc='A stainless steel built-in microwave oven' room_loc='Kitchen'
# item_no=124 item_name='Double oven' item_desc='A stainless steel double wall oven' room_loc='Kitchen'
# item_no=125 item_name='Coffee maker' item_desc='A black coffee maker' room_loc='Kitchen'
# item_no=126 item_name='Vases' item_desc='Two white ceramic vases' room_loc='Kitchen'
# item_no=127 item_name='Juicer' item_desc='A black juicer appliance' room_loc='Kitchen'
#
# Total input tokens: 58170
# Total output tokens: 8297
# Total cost in USD: 0.298965

# %%
import json

# Save catalog_items to catalog_items_first_pass.json
with open('catalog_items_first_pass.json', 'w') as f:
    json.dump([item.dict() for item in catalog_items], f, indent=4)

# Save llm_costs to llm_costs_first_pass.json
with open('llm_costs_first_pass.json', 'w') as f:
    json.dump(llm_costs, f, indent=4)

print('Saved catalog_items and llm_costs to JSON files.')
# Out:
# Saved catalog_items and llm_costs to JSON files.
